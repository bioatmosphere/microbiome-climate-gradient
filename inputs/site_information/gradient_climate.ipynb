# %% [markdown]
# ### Soil temperature data

# %%
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
#import matplotlib.patches as mpatches

print("pandas version:", pd.__version__)
print('numpy version:',  np.__version__)
print('matplotlib version:',  matplotlib.__version__)
# Out:
# pandas version: 0.25.3
# numpy version: 1.18.2
# matplotlib version: 3.1.3

# %% [markdown]
# ### Subalpine

# %%
data1 = pd.read_csv("soil_temperature/Subalpine_plot1_04-20-17-2.csv",skiprows=14)
data1.head()
# Out:
#        Date/Time Unit  Value
# 0   5/14/16 8:02    C   16.0
# 1  5/14/16 12:02    C   32.0
# 2  5/14/16 16:02    C   27.5
# 3  5/14/16 20:02    C   11.5
# 4   5/15/16 0:02    C    9.5

# %%
data1.shape
# Out:
# (2048, 3)

# %%
fig, ax = plt.subplots(1, 1,figsize=(18,5))

ax.plot(data1['Value'],color='red',linewidth=2,alpha=0.6)
plt.show()

# %%
subalpine_data_plot1_1 = pd.read_csv("soil_temperature/Subalpine_plot1_06_16-2.csv",   skiprows=14)
subalpine_data_plot1_2 = pd.read_csv("soil_temperature/Subalpine_plot1_10-23-16-2.csv",skiprows=14)
subalpine_data_plot1_3 = pd.read_csv("soil_temperature/Subalpine_plot1_04-20-17-2.csv",skiprows=14)

# %%
subalpine_data_plot1_1.head()
# Out:
#       Date/Time Unit  Value
# 0  4/4/16 12:02    C   22.5
# 1  4/4/16 16:02    C   22.5
# 2  4/4/16 20:02    C   22.5
# 3   4/5/16 0:02    C   23.0
# 4   4/5/16 4:02    C   23.0

# %%
subalpine_data_plot1_1.tail()
# Out:
#          Date/Time Unit  Value
# 422  6/13/16 20:02    C   15.5
# 423   6/14/16 0:02    C   14.0
# 424   6/14/16 4:02    C   12.5
# 425   6/14/16 8:02    C   22.0
# 426  6/14/16 12:02    C   36.0

# %%
subalpine_data_plot1_2.head()
# Out:
#       Date/Time Unit  Value
# 0  4/4/16 12:02    C   22.5
# 1  4/4/16 16:02    C   22.5
# 2  4/4/16 20:02    C   22.5
# 3   4/5/16 0:02    C   23.0
# 4   4/5/16 4:02    C   23.0

# %%
subalpine_data_plot1_2.tail()
# Out:
#            Date/Time Unit  Value
# 1214  10/23/16 20:02    C   10.0
# 1215   10/24/16 0:02    C   10.5
# 1216   10/24/16 4:02    C    9.5
# 1217   10/24/16 8:02    C    9.0
# 1218  10/24/16 12:02    C   10.0

# %%
subalpine_data_plot1_3.head()
# Out:
#        Date/Time Unit  Value
# 0   5/14/16 8:02    C   16.0
# 1  5/14/16 12:02    C   32.0
# 2  5/14/16 16:02    C   27.5
# 3  5/14/16 20:02    C   11.5
# 4   5/15/16 0:02    C    9.5

# %%
subalpine_data_plot1_3.tail()

# %%
subalpine_data_plot1 = pd.concat([subalpine_data_plot1_1,
                                 subalpine_data_plot1_2,
                                 subalpine_data_plot1_3],
                                axis=0,sort=False)

subalpine_data_plot1.head()
# Out:
#       Date/Time Unit  Value
# 0  4/4/16 12:02    C   22.5
# 1  4/4/16 16:02    C   22.5
# 2  4/4/16 20:02    C   22.5
# 3   4/5/16 0:02    C   23.0
# 4   4/5/16 4:02    C   23.0

# %%
subalpine_data_plot1.tail()
# Out:
#           Date/Time Unit  Value
# 2043  4/19/17 20:02    C   25.0
# 2044   4/20/17 0:02    C   20.0
# 2045   4/20/17 4:02    C   17.0
# 2046   4/20/17 8:02    C   18.5
# 2047  4/20/17 12:02    C   26.5

# %%
subalpine_data_plot1.shape
# Out:
# (3694, 3)

# %%
fig, ax = plt.subplots(1, 1,figsize=(18,5))

ax.plot(subalpine_data_plot1['Value'],color='red',linewidth=2,alpha=0.6)
plt.show()
