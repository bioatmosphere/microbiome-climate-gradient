# %% [markdown]
# ## Statistical analyses of reciprocal transplant simulations
#
# by Bin Wang
#
# @bioatmo_sphere or wbwenwu@gmail.com
#
# UC Irvine & ORNL
#
# 06/11/2021
#
# ---
# Companion of **gradient_analysis_v1.ipynb**.
#
# Structured as follows:
#
# - **Environment and R packages**
#
# - **Gradient analysis**
#
# - **Transplant analysis**
# - - Partitioning variance of substrates/decompostion
# - - Partitioning variance of traits
# - - Regression of decomposition against traits and envs
#
# - **Validation of model with data before transplant**

# %% [markdown]
# ### 0. Computing environment and packages

# %%
library(car)
#library(nlme)
library(lme4)
#library(ggplot2)
print(sessionInfo())
# Out:
# Loading required package: carData
#
# Loading required package: Matrix
#
# Registered S3 methods overwritten by 'lme4':
#   method                          from
#   cooks.distance.influence.merMod car
#   influence.merMod                car
#   dfbeta.influence.merMod         car
#   dfbetas.influence.merMod        car
# R version 4.1.0 (2021-05-18)
# Platform: x86_64-apple-darwin17.0 (64-bit)
# Running under: macOS Big Sur 10.16
#
# Matrix products: default
# BLAS:   /Library/Frameworks/R.framework/Versions/4.1/Resources/lib/libRblas.dylib
# LAPACK: /Library/Frameworks/R.framework/Versions/4.1/Resources/lib/libRlapack.dylib
#
# locale:
# [1] en_US.UTF-8/en_US.UTF-8/en_US.UTF-8/C/en_US.UTF-8/en_US.UTF-8
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] lme4_1.1-27   Matrix_1.3-3  car_3.0-10    carData_3.0-4
#
# loaded via a namespace (and not attached):
#  [1] zip_2.2.0         Rcpp_1.0.6        nloptr_1.2.2.2    pillar_1.6.1
#  [5] compiler_4.1.0    cellranger_1.1.0  forcats_0.5.1     base64enc_0.1-3
#  [9] tools_4.1.0       boot_1.3-28       digest_0.6.27     uuid_0.1-4
# [13] nlme_3.1-152      lattice_0.20-44   jsonlite_1.7.2    evaluate_0.14
# [17] lifecycle_1.0.0   tibble_3.1.2      pkgconfig_2.0.3   rlang_0.4.11
# [21] openxlsx_4.2.3    IRdisplay_1.0     curl_4.3.1        IRkernel_1.2
# [25] haven_2.4.1       rio_0.5.26        repr_1.1.3        vctrs_0.3.8
# [29] hms_1.1.0         grid_4.1.0        data.table_1.14.0 fansi_0.5.0
# [33] readxl_1.3.1      foreign_0.8-81    minqa_1.2.4       pbdZMQ_0.3-5
# [37] magrittr_2.0.1    MASS_7.3-54       splines_4.1.0     ellipsis_0.3.2
# [41] htmltools_0.5.1.1 abind_1.4-5       utf8_1.2.1        stringi_1.6.2
# [45] crayon_1.4.1

# %% [markdown]
# ### 1. Analysis of variance (one-way) of decomposition and traits prior to transplanting
#
# Data of each of the five sites across the gradient (i.e.,before transplanting).

# %%
#define a function of obtaining data of any day
data_origin <- function(sub_data,day){
    
    sub_data_fr <- do.call("cbind.data.frame", sub_data)
    data_decom <- t(sub_data_fr[as.character(day),])
    colnames(data_decom) = 'decom'
    
    site=c('desert','scrubland','grassland','pineoak','subalpine')
    data_origin = cbind(data.frame(origin=rep(site,times=1, each=1*20),site=rep(site,times=1,each=20)),
                       data_decom)
    
    data_origin
}

# %%
#create file list and read the drought tolerance data into a list
file_list <- list()
for (i in 1:5){
    site=c('desert','scrubland','grassland','pineoak','subalpine')
    name<-data.frame(origin=rep(site,times=1,each=1),site=rep(site,times=1,each=1))

    file_list[i] = paste(name$origin[i],"/","Drt_",name$origin[i],"_",name$site[i],'.csv',sep="")
}
drt_data <- lapply(file_list,function(path)read.csv(path,row.names=1))

# %%
drt_anova_d1 <- data_origin(drt_data,1+365*4)
head(drt_anova_d1)
# Out:
#    origin site   decom
# X0 desert desert 0.9596599
# X1 desert desert 0.8840445
# X2 desert desert 0.9605562
# X3 desert desert 0.9160942
# X4 desert desert 0.9103231
# X5 desert desert 0.8969094

# %%
str(drt_anova_d1)
# Out:
# 'data.frame':	100 obs. of  3 variables:
#  $ origin: chr  "desert" "desert" "desert" "desert" ...
#  $ site  : chr  "desert" "desert" "desert" "desert" ...
#  $ decom : num  0.96 0.884 0.961 0.916 0.91 ...

# %%
drt_anova_d1$origin <- factor(drt_anova_d1$origin, levels=c("desert",'scrubland','grassland','pineoak','subalpine'))
boxplot(drt_anova_d1$decom ~ drt_anova_d1$origin,
       xlab = "Site",ylab = 'Drought tolerance',
       col=c("red","orange","green","purple",'blue'),
       cex.lab=1.5,cex.axis=1.2)
# Out:
# plot without title

# %%
fit <- aov(decom ~ origin, data=drt_anova_d1)
summary(fit)
# Out:
#             Df Sum Sq Mean Sq F value Pr(>F)
# origin       4  3.997  0.9992   229.1 <2e-16 ***
# Residuals   95  0.414  0.0044
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
TukeyHSD(fit,'origin',ordered=TRUE)
# Out:
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#     factor levels have been ordered
#
# Fit: aov(formula = decom ~ origin, data = drt_anova_d1)
#
# $origin
#                           diff        lwr       upr     p adj
# pineoak-subalpine   0.09920287 0.04112416 0.1572816 0.0000696
# grassland-subalpine 0.17950363 0.12142492 0.2375823 0.0000000
# scrubland-subalpine 0.42597682 0.36789812 0.4840555 0.0000000
# desert-subalpine    0.53054814 0.47246943 0.5886268 0.0000000
# grassland-pineoak   0.08030076 0.02222205 0.1383795 0.0019942
# scrubland-pineoak   0.32677395 0.26869525 0.3848527 0.0000000
# desert-pineoak      0.43134527 0.37326656 0.4894240 0.0000000
# scrubland-grassland 0.24647319 0.18839449 0.3045519 0.0000000
# desert-grassland    0.35104451 0.29296580 0.4091232 0.0000000
# desert-scrubland    0.10457131 0.04649261 0.1626500 0.0000248

# %%
plot(TukeyHSD(fit,'origin',ordered=TRUE))
# Out:
# Plot with title “95% family-wise confidence level
# ”

# %%
#create file list and read the enzyme trait data into a list
file_list <- list()
for (i in 1:5){
    site=c('desert','scrubland','grassland','pineoak','subalpine')
    name<-data.frame(origin=rep(site,times=1,each=1),site=rep(site,times=1,each=1))

    file_list[i] = paste(name$origin[i],"/","Enz_",name$origin[i],"_",name$site[i],'.csv',sep="")
}
enz_data <- lapply(file_list,function(path)read.csv(path,row.names=1))

# %%
enz_anova_d1 <- data_origin(enz_data,1+365*4)
head(enz_anova_d1)
# Out:
#    origin site   decom
# X0 desert desert 0.0016895419
# X1 desert desert 0.0021747707
# X2 desert desert 0.0011448679
# X3 desert desert 0.0005910701
# X4 desert desert 0.0012781485
# X5 desert desert 0.0019281970

# %%
str(enz_anova_d1)
# Out:
# 'data.frame':	100 obs. of  3 variables:
#  $ origin: chr  "desert" "desert" "desert" "desert" ...
#  $ site  : chr  "desert" "desert" "desert" "desert" ...
#  $ decom : num  0.00169 0.002175 0.001145 0.000591 0.001278 ...

# %%
enz_anova_d1$origin <- factor(enz_anova_d1$origin, levels=c("desert",'scrubland','grassland','pineoak','subalpine'))

boxplot(enz_anova_d1$decom ~ enz_anova_d1$origin,
       xlab = "Site",ylab = 'Enzyme investment',
       col=c("red","orange","green","purple",'blue'),
       cex.lab=1.5,cex.axis=1.2)
# Out:
# plot without title

# %%
fit <- aov(decom ~ origin, data=enz_anova_d1)
summary(fit)
# Out:
#             Df    Sum Sq   Mean Sq F value Pr(>F)
# origin       4 1.598e-06 3.994e-07    2.79 0.0307 *
# Residuals   95 1.360e-05 1.432e-07
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
TukeyHSD(fit,'origin',ordered=TRUE,conf.level = 0.90)
# Out:
#   Tukey multiple comparisons of means
#     90% family-wise confidence level
#     factor levels have been ordered
#
# Fit: aov(formula = decom ~ origin, data = enz_anova_d1)
#
# $origin
#                             diff           lwr          upr     p adj
# grassland-desert    2.570521e-04 -4.169975e-05 0.0005558040 0.2087331
# scrubland-desert    3.043376e-04  5.585745e-06 0.0006030895 0.0897332
# subalpine-desert    3.263549e-04  2.760307e-05 0.0006251068 0.0573174
# pineoak-desert      3.428823e-04  4.413041e-05 0.0006416341 0.0400723
# scrubland-grassland 4.728549e-05 -2.514664e-04 0.0003460374 0.9947690
# subalpine-grassland 6.930282e-05 -2.294490e-04 0.0003680547 0.9778372
# pineoak-grassland   8.583016e-05 -2.129217e-04 0.0003845820 0.9520535
# subalpine-scrubland 2.201733e-05 -2.767345e-04 0.0003207692 0.9997392
# pineoak-scrubland   3.854467e-05 -2.602072e-04 0.0003372965 0.9976315
# pineoak-subalpine   1.652734e-05 -2.822245e-04 0.0003152792 0.9999166

# %%
plot(TukeyHSD(fit,'origin',ordered=TRUE,conf.level = 0.90))
# Out:
# Plot with title “90% family-wise confidence level
# ”

# %%
plot(enz_anova_d1$decom,drt_anova_d1$decom)
# Out:
# plot without title

# %%
##########################################
##### combine the two box plots ##########
##########################################

options(repr.plot.width=15,repr.plot.height=7)

#pdf("figures/community.pdf",width=15,height=7)

par(mfrow=c(1,2),mar=c(5,5,1,1))

boxplot(drt_anova_d1$decom ~ drt_anova_d1$origin,
       xlab = expression(bold("Site")),ylab = expression(bold('Drought tolerance')),
       col=c("red","orange","green","purple",'blue'),
       cex.lab=1.5,cex.axis=1.2,font=2)
text(x=5,y=0.95,"A",col="black",font=1,cex=2.0)

boxplot(enz_anova_d1$decom ~ enz_anova_d1$origin,
       xlab = expression(bold("Site")),ylab = expression(bold('Enzyme investment')),
       col=c("red","orange","green","purple",'blue'),
       cex.lab=1.5,cex.axis=1.2,font=2)

text(x=5,y=0.0027,"B",col="black",font=1,cex=2.0)

#dev.off()
# Out:
# plot without title

# %%
#create file list and read the substrates data into a list
file_list <- list()
for (i in 1:5){
    site=c('desert','scrubland','grassland','pineoak','subalpine')
    name<-data.frame(origin=rep(site,times=1,each=1),site=rep(site,times=1,each=1))

    file_list[i] = paste(name$origin[i],"/","Sub_",name$origin[i],"_",name$site[i],'.csv',sep="")
}
sub_data <- lapply(file_list,function(path)read.csv(path,row.names=1))

# %%
sub_anova_d1 <- data_origin(sub_data,1+365*4 - 1)
head(sub_anova_d1)
# Out:
#    origin site   decom
# X0 desert desert 2557969
# X1 desert desert 2598060
# X2 desert desert 2880928
# X3 desert desert 3073738
# X4 desert desert 2559100
# X5 desert desert 2566868

# %%
#new_order <- with(sub_anova_d1,reorder())

sub_anova_d1$origin <- factor(sub_anova_d1$origin, levels=c("desert",'scrubland','grassland','pineoak','subalpine'))
boxplot(sub_anova_d1$decom ~ sub_anova_d1$origin)
# Out:
# plot without title

# %%
fit <- aov(decom ~ origin, data=sub_anova_d1)
summary(fit)
# Out:
#             Df    Sum Sq   Mean Sq F value Pr(>F)
# origin       4 7.025e+13 1.756e+13   94.13 <2e-16 ***
# Residuals   95 1.772e+13 1.866e+11
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
TukeyHSD(fit,'origin',ordered=TRUE,conf.level = 0.95)
# Out:
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#     factor levels have been ordered
#
# Fit: aov(formula = decom ~ origin, data = sub_anova_d1)
#
# $origin
#                          diff         lwr       upr     p adj
# subalpine-pineoak    388318.9    8474.778  768163.0 0.0425350
# grassland-pineoak    805173.4  425329.309 1185017.5 0.0000006
# scrubland-pineoak   1779407.0 1399562.901 2159251.1 0.0000000
# desert-pineoak      2225018.2 1845174.086 2604862.3 0.0000000
# grassland-subalpine  416854.5   37010.418  796698.6 0.0240480
# scrubland-subalpine 1391088.1 1011244.010 1770932.2 0.0000000
# desert-subalpine    1836699.3 1456855.195 2216543.4 0.0000000
# scrubland-grassland  974233.6  594389.479 1354077.7 0.0000000
# desert-grassland    1419844.8 1040000.664 1799688.9 0.0000000
# desert-scrubland     445611.2   65767.072  825455.3 0.0130270

# %%
plot(TukeyHSD(fit,'origin',ordered=TRUE,conf.level = 0.95))
# Out:
# Plot with title “95% family-wise confidence level
# ”

# %% [markdown]
# ### 2. Analysis of transplant data
#
# These data cover 4 x 365 days of decomposition and traits structured by a 5x5 (n=20) factorial design

# %% [markdown]
# #### 2.1. Analysis of variance of litter decomposition
#
# ANOVA with a linear model at different time points were performed.
#
# Ensure assumptions met!
#
# - Homogeneity of Variance: https://www.datanovia.com/en/lessons/homogeneity-of-variance-test-in-r/
# - Transforming data: https://rcompanion.org/handbook/I_12.html
#
# References:
# - https://www.statmethods.net/stats/anova.html
# - **mixed model analysis of variance**--theory: https://sk.sagepub.com/reference/sage-encyclopedia-of-educational-research-measurement-evaluation/i13711.xml; implementation: https://rpsychologist.com/r-guide-longitudinal-lme-lmer
#
# **NOTE**: The experimentation starts from year 5 (on day 365*4+1)

# %%
#define a universal function of obtaining data of any day
data_anova <- function(sub_data,day){
    
    sub_data_fr <- do.call("cbind.data.frame", sub_data)
    data_decom <- t(sub_data_fr[as.character(day),])
    colnames(data_decom) = 'decom'
    
    site=c('desert','scrubland','grassland','pineoak','subalpine')
    data_anova = cbind(data.frame(origin=rep(site,times=1, each=5*20),site=rep(site,times=5,each=20)),
                       data_decom)
    
    data_anova
}

# %%
#create file list and read the source decomposition data into a list
file_list <- list()
for (i in 1:25){
    site=c('desert','scrubland','grassland','pineoak','subalpine')
    name<-data.frame(origin=rep(site,times=1,each=5),site=rep(site,times=5,each=1))

    file_list[i] = paste(name$origin[i],"/","Sub_",name$origin[i],"_",name$site[i],'.csv',sep="")
}
sub_data <- lapply(file_list,function(path)read.csv(path,row.names=1))

# %%
# obtain data of the "last" day of the 1st year transplant
data_anova_d1 <- data_anova(sub_data,1+365*4 + 365 - 1)
data_anova_d1[,'decom'] <- data_anova_d1$decom/10000
head(data_anova_d1)
# Out:
#    origin site   decom
# X0 desert desert 260.4377
# X1 desert desert 259.2960
# X2 desert desert 289.8874
# X3 desert desert 309.1437
# X4 desert desert 255.3615
# X5 desert desert 263.3692

# %%
fit_d1 <- aov(decom ~ origin + site + origin:site, data=data_anova_d1)
summary(fit_d1)
# Out:
#              Df  Sum Sq Mean Sq F value Pr(>F)
# origin        4  611338  152835  61.512 <2e-16 ***
# site          4 1613983  403496 162.396 <2e-16 ***
# origin:site  16   67728    4233   1.704 0.0427 *
# Residuals   475 1180202    2485
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
cat('Contribution by each factor:',summary(fit_d1)[[1]]$'Sum Sq'/sum(summary(fit_d1)[[1]]$'Sum Sq'))
# Out:
# Contribution by each factor: 0.1760132 0.4646893 0.0194999 0.3397976

# %%
# obtain data of the "last" day of the "last(4th)"" year transplant
data_anova_d2 <- data_anova(sub_data,1+365*4 + 365*4 - 1)
data_anova_d2[,'decom'] <- data_anova_d2$decom/10000
head(data_anova_d2)
# Out:
#    origin site   decom
# X0 desert desert 269.9034
# X1 desert desert 261.5293
# X2 desert desert 290.3816
# X3 desert desert 310.0326
# X4 desert desert 257.3524
# X5 desert desert 272.3189

# %%
fit_d2 <- aov(decom ~ origin + site + origin:site, data=data_anova_d2)
summary(fit_d2)
# Out:
#              Df  Sum Sq Mean Sq F value   Pr(>F)
# origin        4  164719   41180  17.481 2.15e-13 ***
# site          4 2939946  734986 312.012  < 2e-16 ***
# origin:site  16   62835    3927   1.667   0.0495 *
# Residuals   475 1118925    2356
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
cat('Contribution by each factor:',summary(fit_d2)[[1]]$'Sum Sq'/sum(summary(fit_d2)[[1]]$'Sum Sq'))
# Out:
# Contribution by each factor: 0.03842806 0.6858736 0.01465909 0.2610392

# %% [markdown]
# #### 2.2 Analysis of variance of Traits
#
# to dissentangle factors (history and local condiditions), and to what extent these factors, shape community traits.

# %%
###### enzyme investment
#create a file list and read the decomposition data into a list
file_list <- list()
for (i in 1:25){
    site=c('desert','scrubland','grassland','pineoak','subalpine')
    name<-data.frame(origin=rep(site,times=1,each=5),site=rep(site,times=5,each=1))

    file_list[i] = paste(name$origin[i],"/","Enz_",name$origin[i],"_",name$site[i],'.csv',sep="")
}
enz_data <- lapply(file_list,function(path)read.csv(path,row.names=1))

# %%
# Last day in the very 1st year
enz_data_d0 <- data_anova(enz_data,1+365*4 + 365 - 1)
head(enz_data_d0)
# Out:
#    origin site   decom
# X0 desert desert 0.0016435153
# X1 desert desert 0.0021950307
# X2 desert desert 0.0011091144
# X3 desert desert 0.0005713315
# X4 desert desert 0.0013090709
# X5 desert desert 0.0019363400

# %%
# homogeneity of variance
boxplot(decom ~ site,data=enz_data_d0[enz_data_d0['origin'] == 'desert',])
boxplot(decom ~ site,data=enz_data_d0[enz_data_d0['origin'] == 'scrubland',])
boxplot(decom ~ site,data=enz_data_d0[enz_data_d0['origin'] == 'grassland',])
boxplot(decom ~ site,data=enz_data_d0[enz_data_d0['origin'] == 'pineoak',])
boxplot(decom ~ site,data=enz_data_d0[enz_data_d0['origin'] == 'subalpine',])
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %%
## homogeneity of variance
leveneTest(decom ~ origin*site, data=enz_data_d0)
# Out:
#       Df  F value  Pr(>F)
# group  24 3.749166 1.251114e-08
#       475       NA           NA

# %%
enz_data_d0_de_de = enz_data_d0[enz_data_d0['origin'] == 'desert' & enz_data_d0['site'] == 'desert',]
hist(enz_data_d0_de_de$decom)
qqnorm(enz_data_d0_de_de$decom,ylab="Sample Quantiles for decom")
qqline(enz_data_d0_de_de$decom,col="red")

# enz_data_d0_su_su = enz_data_d0[enz_data_d0['origin'] == 'subalpine' & enz_data_d0['site'] == 'subalpine',]
# hist(log(enz_data_d0_su_su$decom))
# qqnorm(log(enz_data_d0_su_su$decom),ylab="Sample Quantiles for decom")
# qqline(log(enz_data_d0_su_su$decom),col="red")
# Out:
# Plot with title “Histogram of enz_data_d0_de_de$decom”
# Plot with title “Normal Q-Q Plot”

# %%
enz_fit_d0 <- aov(decom ~ origin + site + origin:site, data=enz_data_d0)
summary(enz_fit_d0)
# Out:
#              Df    Sum Sq   Mean Sq F value   Pr(>F)
# origin        4 3.630e-06 9.084e-07   5.663 0.000185 ***
# site          4 2.510e-06 6.263e-07   3.904 0.003942 **
# origin:site  16 7.300e-07 4.570e-08   0.285 0.997393
# Residuals   475 7.619e-05 1.604e-07
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
cat('Contribution by each factor:',summary(enz_fit_d0)[[1]]$'Sum Sq'/sum(summary(enz_fit_d0)[[1]]$'Sum Sq'))
# Out:
# Contribution by each factor: 0.04374423 0.03015943 0.008806626 0.9172897

# %%
TukeyHSD(enz_fit_d0,ordered=TRUE)
# Out:
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#     factor levels have been ordered
#
# Fit: aov(formula = decom ~ origin + site + origin:site, data = enz_data_d0)
#
# $origin
#                             diff           lwr          upr     p adj
# grassland-desert    1.974717e-04  4.237629e-05 0.0003525670 0.0048385
# scrubland-desert    2.089357e-04  5.384037e-05 0.0003640311 0.0023269
# subalpine-desert    2.191802e-04  6.408486e-05 0.0003742756 0.0011691
# pineoak-desert      2.224008e-04  6.730544e-05 0.0003774962 0.0009355
# scrubland-grassland 1.146408e-05 -1.436313e-04 0.0001665595 0.9996254
# subalpine-grassland 2.170856e-05 -1.333868e-04 0.0001768039 0.9954165
# pineoak-grassland   2.492915e-05 -1.301662e-04 0.0001800245 0.9922006
# subalpine-scrubland 1.024448e-05 -1.448509e-04 0.0001653399 0.9997602
# pineoak-scrubland   1.346507e-05 -1.416303e-04 0.0001685604 0.9992923
# pineoak-subalpine   3.220584e-06 -1.518748e-04 0.0001583160 0.9999976
#
# $site
#                             diff           lwr          upr     p adj
# grassland-desert    9.666045e-05 -5.843492e-05 0.0002517558 0.4308272
# scrubland-desert    1.500903e-04 -5.005078e-06 0.0003051857 0.0632531
# subalpine-desert    1.682373e-04  1.314191e-05 0.0003233327 0.0258561
# pineoak-desert      2.033109e-04  4.821554e-05 0.0003584063 0.0033496
# scrubland-grassland 5.342984e-05 -1.016655e-04 0.0002085252 0.8797895
# subalpine-grassland 7.157683e-05 -8.351854e-05 0.0002266722 0.7136135
# pineoak-grassland   1.066505e-04 -4.844491e-05 0.0002617458 0.3279147
# subalpine-scrubland 1.814699e-05 -1.369484e-04 0.0001732424 0.9977152
# pineoak-scrubland   5.322062e-05 -1.018748e-04 0.0002083160 0.8812995
# pineoak-subalpine   3.507363e-05 -1.200217e-04 0.0001901690 0.9719956
#
# $`origin:site`
#                                                 diff           lwr          upr
# desert:scrubland-desert:desert          7.168246e-05 -3.943870e-04 0.0005377520
# desert:grassland-desert:desert          1.048375e-04 -3.612320e-04 0.0005709070
# grassland:desert-desert:desert          1.317100e-04 -3.343595e-04 0.0005977795
# scrubland:desert-desert:desert          1.372684e-04 -3.288011e-04 0.0006033379
# desert:subalpine-desert:desert          1.536118e-04 -3.124577e-04 0.0006196813
# desert:pineoak-desert:desert            2.047968e-04 -2.612727e-04 0.0006708663
# subalpine:desert-desert:desert          2.430605e-04 -2.230090e-04 0.0007091300
# pineoak:desert-desert:desert            2.525791e-04 -2.134904e-04 0.0007186486
# grassland:grassland-desert:desert       2.764482e-04 -1.896213e-04 0.0007425177
# subalpine:grassland-desert:desert       2.840258e-04 -1.820437e-04 0.0007500953
# pineoak:grassland-desert:desert         2.912633e-04 -1.748062e-04 0.0007573328
# scrubland:grassland-desert:desert       2.913455e-04 -1.747240e-04 0.0007574150
# scrubland:scrubland-desert:desert       3.000595e-04 -1.660100e-04 0.0007661290
# grassland:scrubland-desert:desert       3.252208e-04 -1.408487e-04 0.0007912903
# pineoak:subalpine-desert:desert         3.297917e-04 -1.362778e-04 0.0007958612
# subalpine:subalpine-desert:desert       3.417538e-04 -1.243157e-04 0.0008078233
# subalpine:pineoak-desert:desert         3.536256e-04 -1.124439e-04 0.0008196951
# pineoak:pineoak-desert:desert           3.635558e-04 -1.025137e-04 0.0008296253
# grassland:subalpine-desert:desert       3.848843e-04 -8.118515e-05 0.0008509538
# scrubland:subalpine-desert:desert       3.957629e-04 -7.030661e-05 0.0008618324
# grassland:pineoak-desert:desert         4.040235e-04 -6.204596e-05 0.0008700930
# subalpine:scrubland-desert:desert       4.083640e-04 -5.770549e-05 0.0008744335
# pineoak:scrubland-desert:desert         4.097427e-04 -5.632680e-05 0.0008758122
# scrubland:pineoak-desert:desert         4.551709e-04 -1.089857e-05 0.0009212404
# desert:grassland-desert:scrubland       3.315504e-05 -4.329145e-04 0.0004992245
# grassland:desert-desert:scrubland       6.002752e-05 -4.060420e-04 0.0005260970
# scrubland:desert-desert:scrubland       6.558597e-05 -4.004835e-04 0.0005316555
# desert:subalpine-desert:scrubland       8.192929e-05 -3.841402e-04 0.0005479988
# desert:pineoak-desert:scrubland         1.331144e-04 -3.329551e-04 0.0005991839
# subalpine:desert-desert:scrubland       1.713780e-04 -2.946914e-04 0.0006374475
# pineoak:desert-desert:scrubland         1.808967e-04 -2.851728e-04 0.0006469662
# grassland:grassland-desert:scrubland    2.047657e-04 -2.613038e-04 0.0006708352
# subalpine:grassland-desert:scrubland    2.123434e-04 -2.537261e-04 0.0006784129
# pineoak:grassland-desert:scrubland      2.195808e-04 -2.464887e-04 0.0006856503
# scrubland:grassland-desert:scrubland    2.196630e-04 -2.464064e-04 0.0006857325
# scrubland:scrubland-desert:scrubland    2.283771e-04 -2.376924e-04 0.0006944466
# grassland:scrubland-desert:scrubland    2.535384e-04 -2.125311e-04 0.0007196079
# pineoak:subalpine-desert:scrubland      2.581093e-04 -2.079602e-04 0.0007241788
# subalpine:subalpine-desert:scrubland    2.700713e-04 -1.959982e-04 0.0007361408
# subalpine:pineoak-desert:scrubland      2.819431e-04 -1.841264e-04 0.0007480126
# pineoak:pineoak-desert:scrubland        2.918733e-04 -1.741962e-04 0.0007579428
# grassland:subalpine-desert:scrubland    3.132019e-04 -1.528676e-04 0.0007792714
# scrubland:subalpine-desert:scrubland    3.240804e-04 -1.419891e-04 0.0007901499
# grassland:pineoak-desert:scrubland      3.323411e-04 -1.337284e-04 0.0007984106
# subalpine:scrubland-desert:scrubland    3.366815e-04 -1.293880e-04 0.0008027510
# pineoak:scrubland-desert:scrubland      3.380602e-04 -1.280093e-04 0.0008041297
# scrubland:pineoak-desert:scrubland      3.834885e-04 -8.258104e-05 0.0008495580
# grassland:desert-desert:grassland       2.687248e-05 -4.391970e-04 0.0004929420
# scrubland:desert-desert:grassland       3.243093e-05 -4.336386e-04 0.0004985004
# desert:subalpine-desert:grassland       4.877425e-05 -4.172952e-04 0.0005148438
# desert:pineoak-desert:grassland         9.995932e-05 -3.661102e-04 0.0005660288
# subalpine:desert-desert:grassland       1.382230e-04 -3.278465e-04 0.0006042925
# pineoak:desert-desert:grassland         1.477416e-04 -3.183279e-04 0.0006138111
# grassland:grassland-desert:grassland    1.716107e-04 -2.944588e-04 0.0006376802
# subalpine:grassland-desert:grassland    1.791883e-04 -2.868812e-04 0.0006452578
# pineoak:grassland-desert:grassland      1.864258e-04 -2.796437e-04 0.0006524953
# scrubland:grassland-desert:grassland    1.865080e-04 -2.795615e-04 0.0006525775
# scrubland:scrubland-desert:grassland    1.952220e-04 -2.708475e-04 0.0006612915
# grassland:scrubland-desert:grassland    2.203833e-04 -2.456862e-04 0.0006864528
# pineoak:subalpine-desert:grassland      2.249542e-04 -2.411153e-04 0.0006910237
# subalpine:subalpine-desert:grassland    2.369163e-04 -2.291532e-04 0.0007029858
# subalpine:pineoak-desert:grassland      2.487881e-04 -2.172814e-04 0.0007148576
# pineoak:pineoak-desert:grassland        2.587183e-04 -2.073512e-04 0.0007247878
# grassland:subalpine-desert:grassland    2.800468e-04 -1.860227e-04 0.0007461163
# scrubland:subalpine-desert:grassland    2.909254e-04 -1.751441e-04 0.0007569949
# grassland:pineoak-desert:grassland      2.991860e-04 -1.668835e-04 0.0007652555
# subalpine:scrubland-desert:grassland    3.035265e-04 -1.625430e-04 0.0007695960
# pineoak:scrubland-desert:grassland      3.049052e-04 -1.611643e-04 0.0007709747
# scrubland:pineoak-desert:grassland      3.503334e-04 -1.157361e-04 0.0008164029
# scrubland:desert-grassland:desert       5.558450e-06 -4.605110e-04 0.0004716279
# desert:subalpine-grassland:desert       2.190177e-05 -4.441677e-04 0.0004879713
# desert:pineoak-grassland:desert         7.308684e-05 -3.929827e-04 0.0005391563
# subalpine:desert-grassland:desert       1.113505e-04 -3.547190e-04 0.0005774200
# pineoak:desert-grassland:desert         1.208691e-04 -3.452004e-04 0.0005869386
# grassland:grassland-grassland:desert    1.447382e-04 -3.213313e-04 0.0006108077
# subalpine:grassland-grassland:desert    1.523158e-04 -3.137537e-04 0.0006183853
# pineoak:grassland-grassland:desert      1.595533e-04 -3.065162e-04 0.0006256228
# scrubland:grassland-grassland:desert    1.596355e-04 -3.064340e-04 0.0006257050
# scrubland:scrubland-grassland:desert    1.683495e-04 -2.977199e-04 0.0006344190
# grassland:scrubland-grassland:desert    1.935108e-04 -2.725587e-04 0.0006595803
# pineoak:subalpine-grassland:desert      1.980817e-04 -2.679878e-04 0.0006641512
# subalpine:subalpine-grassland:desert    2.100438e-04 -2.560257e-04 0.0006761133
# subalpine:pineoak-grassland:desert      2.219156e-04 -2.441539e-04 0.0006879851
# pineoak:pineoak-grassland:desert        2.318458e-04 -2.342237e-04 0.0006979153
# grassland:subalpine-grassland:desert    2.531744e-04 -2.128951e-04 0.0007192439
# scrubland:subalpine-grassland:desert    2.640529e-04 -2.020166e-04 0.0007301224
# grassland:pineoak-grassland:desert      2.723136e-04 -1.937559e-04 0.0007383830
# subalpine:scrubland-grassland:desert    2.766540e-04 -1.894155e-04 0.0007427235
# pineoak:scrubland-grassland:desert      2.780327e-04 -1.880368e-04 0.0007441022
# scrubland:pineoak-grassland:desert      3.234609e-04 -1.426086e-04 0.0007895304
# desert:subalpine-scrubland:desert       1.634332e-05 -4.497262e-04 0.0004824128
# desert:pineoak-scrubland:desert         6.752839e-05 -3.985411e-04 0.0005335979
# subalpine:desert-scrubland:desert       1.057921e-04 -3.602774e-04 0.0005718616
# pineoak:desert-scrubland:desert         1.153107e-04 -3.507588e-04 0.0005813802
# grassland:grassland-scrubland:desert    1.391798e-04 -3.268897e-04 0.0006052493
# subalpine:grassland-scrubland:desert    1.467574e-04 -3.193121e-04 0.0006128269
# pineoak:grassland-scrubland:desert      1.539949e-04 -3.120746e-04 0.0006200644
# scrubland:grassland-scrubland:desert    1.540771e-04 -3.119924e-04 0.0006201466
# scrubland:scrubland-scrubland:desert    1.627911e-04 -3.032784e-04 0.0006288606
# grassland:scrubland-scrubland:desert    1.879524e-04 -2.781171e-04 0.0006540219
# pineoak:subalpine-scrubland:desert      1.925233e-04 -2.735462e-04 0.0006585928
# subalpine:subalpine-scrubland:desert    2.044853e-04 -2.615842e-04 0.0006705548
# subalpine:pineoak-scrubland:desert      2.163571e-04 -2.497124e-04 0.0006824266
# pineoak:pineoak-scrubland:desert        2.262873e-04 -2.397822e-04 0.0006923568
# grassland:subalpine-scrubland:desert    2.476159e-04 -2.184536e-04 0.0007136854
# scrubland:subalpine-scrubland:desert    2.584944e-04 -2.075751e-04 0.0007245639
# grassland:pineoak-scrubland:desert      2.667551e-04 -1.993144e-04 0.0007328246
# subalpine:scrubland-scrubland:desert    2.710956e-04 -1.949739e-04 0.0007371651
# pineoak:scrubland-scrubland:desert      2.724743e-04 -1.935952e-04 0.0007385438
# scrubland:pineoak-scrubland:desert      3.179025e-04 -1.481670e-04 0.0007839720
# desert:pineoak-desert:subalpine         5.118507e-05 -4.148844e-04 0.0005172546
# subalpine:desert-desert:subalpine       8.944875e-05 -3.766207e-04 0.0005555183
# pineoak:desert-desert:subalpine         9.896736e-05 -3.671021e-04 0.0005650369
# grassland:grassland-desert:subalpine    1.228364e-04 -3.432331e-04 0.0005889059
# subalpine:grassland-desert:subalpine    1.304141e-04 -3.356554e-04 0.0005964836
# pineoak:grassland-desert:subalpine      1.376515e-04 -3.284180e-04 0.0006037210
# scrubland:grassland-desert:subalpine    1.377338e-04 -3.283357e-04 0.0006038033
# scrubland:scrubland-desert:subalpine    1.464478e-04 -3.196217e-04 0.0006125173
# grassland:scrubland-desert:subalpine    1.716091e-04 -2.944604e-04 0.0006376786
# pineoak:subalpine-desert:subalpine      1.761800e-04 -2.898895e-04 0.0006422495
# subalpine:subalpine-desert:subalpine    1.881420e-04 -2.779275e-04 0.0006542115
# subalpine:pineoak-desert:subalpine      2.000138e-04 -2.660557e-04 0.0006660833
# pineoak:pineoak-desert:subalpine        2.099440e-04 -2.561255e-04 0.0006760135
# grassland:subalpine-desert:subalpine    2.312726e-04 -2.347969e-04 0.0006973421
# scrubland:subalpine-desert:subalpine    2.421511e-04 -2.239184e-04 0.0007082206
# grassland:pineoak-desert:subalpine      2.504118e-04 -2.156577e-04 0.0007164813
# subalpine:scrubland-desert:subalpine    2.547522e-04 -2.113172e-04 0.0007208217
# pineoak:scrubland-desert:subalpine      2.561309e-04 -2.099386e-04 0.0007222004
# scrubland:pineoak-desert:subalpine      3.015592e-04 -1.645103e-04 0.0007676287
# subalpine:desert-desert:pineoak         3.826369e-05 -4.278058e-04 0.0005043332
# pineoak:desert-desert:pineoak           4.778230e-05 -4.182872e-04 0.0005138518
# grassland:grassland-desert:pineoak      7.165137e-05 -3.944181e-04 0.0005377209
# subalpine:grassland-desert:pineoak      7.922901e-05 -3.868405e-04 0.0005452985
# pineoak:grassland-desert:pineoak        8.646647e-05 -3.796030e-04 0.0005525360
# scrubland:grassland-desert:pineoak      8.654869e-05 -3.795208e-04 0.0005526182
# scrubland:scrubland-desert:pineoak      9.526271e-05 -3.708068e-04 0.0005613322
# grassland:scrubland-desert:pineoak      1.204240e-04 -3.456455e-04 0.0005864935
# pineoak:subalpine-desert:pineoak        1.249949e-04 -3.410746e-04 0.0005910644
# subalpine:subalpine-desert:pineoak      1.369569e-04 -3.291126e-04 0.0006030264
# subalpine:pineoak-desert:pineoak        1.488288e-04 -3.172407e-04 0.0006148983
# pineoak:pineoak-desert:pineoak          1.587589e-04 -3.073106e-04 0.0006248284
# grassland:subalpine-desert:pineoak      1.800875e-04 -2.859820e-04 0.0006461570
# scrubland:subalpine-desert:pineoak      1.909661e-04 -2.751034e-04 0.0006570356
# grassland:pineoak-desert:pineoak        1.992267e-04 -2.668428e-04 0.0006652962
# subalpine:scrubland-desert:pineoak      2.035672e-04 -2.625023e-04 0.0006696367
# pineoak:scrubland-desert:pineoak        2.049459e-04 -2.611236e-04 0.0006710154
# scrubland:pineoak-desert:pineoak        2.503741e-04 -2.156954e-04 0.0007164436
# pineoak:desert-subalpine:desert         9.518610e-06 -4.565509e-04 0.0004755881
# grassland:grassland-subalpine:desert    3.338768e-05 -4.326818e-04 0.0004994572
# subalpine:grassland-subalpine:desert    4.096532e-05 -4.251042e-04 0.0005070348
# pineoak:grassland-subalpine:desert      4.820278e-05 -4.178667e-04 0.0005142723
# scrubland:grassland-subalpine:desert    4.828500e-05 -4.177845e-04 0.0005143545
# scrubland:scrubland-subalpine:desert    5.699902e-05 -4.090705e-04 0.0005230685
# grassland:scrubland-subalpine:desert    8.216031e-05 -3.839092e-04 0.0005482298
# pineoak:subalpine-subalpine:desert      8.673122e-05 -3.793383e-04 0.0005528007
# subalpine:subalpine-subalpine:desert    9.869325e-05 -3.673762e-04 0.0005647627
# subalpine:pineoak-subalpine:desert      1.105651e-04 -3.555044e-04 0.0005766346
# pineoak:pineoak-subalpine:desert        1.204953e-04 -3.455742e-04 0.0005865648
# grassland:subalpine-subalpine:desert    1.418238e-04 -3.242457e-04 0.0006078933
# scrubland:subalpine-subalpine:desert    1.527024e-04 -3.133671e-04 0.0006187719
# grassland:pineoak-subalpine:desert      1.609630e-04 -3.051065e-04 0.0006270325
# subalpine:scrubland-subalpine:desert    1.653035e-04 -3.007660e-04 0.0006313730
# pineoak:scrubland-subalpine:desert      1.666822e-04 -2.993873e-04 0.0006327517
# scrubland:pineoak-subalpine:desert      2.121104e-04 -2.539591e-04 0.0006781799
# grassland:grassland-pineoak:desert      2.386907e-05 -4.422004e-04 0.0004899386
# subalpine:grassland-pineoak:desert      3.144671e-05 -4.346228e-04 0.0004975162
# pineoak:grassland-pineoak:desert        3.868417e-05 -4.273853e-04 0.0005047537
# scrubland:grassland-pineoak:desert      3.876639e-05 -4.273031e-04 0.0005048359
# scrubland:scrubland-pineoak:desert      4.748041e-05 -4.185891e-04 0.0005135499
# grassland:scrubland-pineoak:desert      7.264170e-05 -3.934278e-04 0.0005387112
# pineoak:subalpine-pineoak:desert        7.721261e-05 -3.888569e-04 0.0005432821
# subalpine:subalpine-pineoak:desert      8.917464e-05 -3.768949e-04 0.0005552441
# subalpine:pineoak-pineoak:desert        1.010465e-04 -3.650230e-04 0.0005671160
# pineoak:pineoak-pineoak:desert          1.109766e-04 -3.550928e-04 0.0005770461
# grassland:subalpine-pineoak:desert      1.323052e-04 -3.337643e-04 0.0005983747
# scrubland:subalpine-pineoak:desert      1.431838e-04 -3.228857e-04 0.0006092533
# grassland:pineoak-pineoak:desert        1.514444e-04 -3.146251e-04 0.0006175139
# subalpine:scrubland-pineoak:desert      1.557849e-04 -3.102846e-04 0.0006218544
# pineoak:scrubland-pineoak:desert        1.571636e-04 -3.089059e-04 0.0006232331
# scrubland:pineoak-pineoak:desert        2.025918e-04 -2.634777e-04 0.0006686613
# subalpine:grassland-grassland:grassland 7.577640e-06 -4.584919e-04 0.0004736471
# pineoak:grassland-grassland:grassland   1.481510e-05 -4.512544e-04 0.0004808846
# scrubland:grassland-grassland:grassland 1.489732e-05 -4.511722e-04 0.0004809668
# scrubland:scrubland-grassland:grassland 2.361134e-05 -4.424582e-04 0.0004896808
# grassland:scrubland-grassland:grassland 4.877264e-05 -4.172969e-04 0.0005148421
# pineoak:subalpine-grassland:grassland   5.334354e-05 -4.127260e-04 0.0005194130
# subalpine:subalpine-grassland:grassland 6.530557e-05 -4.007639e-04 0.0005313751
# subalpine:pineoak-grassland:grassland   7.717739e-05 -3.888921e-04 0.0005432469
# pineoak:pineoak-grassland:grassland     8.710758e-05 -3.789619e-04 0.0005531771
# grassland:subalpine-grassland:grassland 1.084362e-04 -3.576333e-04 0.0005745056
# scrubland:subalpine-grassland:grassland 1.193147e-04 -3.467548e-04 0.0005853842
# grassland:pineoak-grassland:grassland   1.275753e-04 -3.384942e-04 0.0005936448
# subalpine:scrubland-grassland:grassland 1.319158e-04 -3.341537e-04 0.0005979853
# pineoak:scrubland-grassland:grassland   1.332945e-04 -3.327750e-04 0.0005993640
# scrubland:pineoak-grassland:grassland   1.787227e-04 -2.873468e-04 0.0006447922
# pineoak:grassland-subalpine:grassland   7.237460e-06 -4.588320e-04 0.0004733070
# scrubland:grassland-subalpine:grassland 7.319680e-06 -4.587498e-04 0.0004733892
# scrubland:scrubland-subalpine:grassland 1.603370e-05 -4.500358e-04 0.0004821032
# grassland:scrubland-subalpine:grassland 4.119499e-05 -4.248745e-04 0.0005072645
# pineoak:subalpine-subalpine:grassland   4.576590e-05 -4.203036e-04 0.0005118354
# subalpine:subalpine-subalpine:grassland 5.772793e-05 -4.083416e-04 0.0005237974
# subalpine:pineoak-subalpine:grassland   6.959975e-05 -3.964697e-04 0.0005356692
# pineoak:pineoak-subalpine:grassland     7.952994e-05 -3.865396e-04 0.0005455994
# grassland:subalpine-subalpine:grassland 1.008585e-04 -3.652110e-04 0.0005669280
# scrubland:subalpine-subalpine:grassland 1.117370e-04 -3.543324e-04 0.0005778065
# grassland:pineoak-subalpine:grassland   1.199977e-04 -3.460718e-04 0.0005860672
# subalpine:scrubland-subalpine:grassland 1.243382e-04 -3.417313e-04 0.0005904077
# pineoak:scrubland-subalpine:grassland   1.257169e-04 -3.403526e-04 0.0005917864
# scrubland:pineoak-subalpine:grassland   1.711451e-04 -2.949244e-04 0.0006372146
# scrubland:grassland-pineoak:grassland   8.222000e-08 -4.659873e-04 0.0004661517
# scrubland:scrubland-pineoak:grassland   8.796245e-06 -4.572733e-04 0.0004748657
# grassland:scrubland-pineoak:grassland   3.395754e-05 -4.321120e-04 0.0005000270
# pineoak:subalpine-pineoak:grassland     3.852844e-05 -4.275411e-04 0.0005045979
# subalpine:subalpine-pineoak:grassland   5.049047e-05 -4.155790e-04 0.0005165600
# subalpine:pineoak-pineoak:grassland     6.236229e-05 -4.037072e-04 0.0005284318
# pineoak:pineoak-pineoak:grassland       7.229248e-05 -3.937770e-04 0.0005383620
# grassland:subalpine-pineoak:grassland   9.362105e-05 -3.724484e-04 0.0005596905
# scrubland:subalpine-pineoak:grassland   1.044996e-04 -3.615699e-04 0.0005705691
# grassland:pineoak-pineoak:grassland     1.127602e-04 -3.533093e-04 0.0005788297
# subalpine:scrubland-pineoak:grassland   1.171007e-04 -3.489688e-04 0.0005831702
# pineoak:scrubland-pineoak:grassland     1.184794e-04 -3.475901e-04 0.0005845489
# scrubland:pineoak-pineoak:grassland     1.639076e-04 -3.021619e-04 0.0006299771
# scrubland:scrubland-scrubland:grassland 8.714025e-06 -4.573555e-04 0.0004747835
# grassland:scrubland-scrubland:grassland 3.387532e-05 -4.321942e-04 0.0004999448
# pineoak:subalpine-scrubland:grassland   3.844622e-05 -4.276233e-04 0.0005045157
# subalpine:subalpine-scrubland:grassland 5.040825e-05 -4.156612e-04 0.0005164777
# subalpine:pineoak-scrubland:grassland   6.228007e-05 -4.037894e-04 0.0005283496
# pineoak:pineoak-scrubland:grassland     7.221026e-05 -3.938592e-04 0.0005382798
# grassland:subalpine-scrubland:grassland 9.353883e-05 -3.725307e-04 0.0005596083
# scrubland:subalpine-scrubland:grassland 1.044174e-04 -3.616521e-04 0.0005704869
# grassland:pineoak-scrubland:grassland   1.126780e-04 -3.533915e-04 0.0005787475
# subalpine:scrubland-scrubland:grassland 1.170185e-04 -3.490510e-04 0.0005830880
# pineoak:scrubland-scrubland:grassland   1.183972e-04 -3.476723e-04 0.0005844667
# scrubland:pineoak-scrubland:grassland   1.638254e-04 -3.022441e-04 0.0006298949
# grassland:scrubland-scrubland:scrubland 2.516129e-05 -4.409082e-04 0.0004912308
# pineoak:subalpine-scrubland:scrubland   2.973220e-05 -4.363373e-04 0.0004958017
# subalpine:subalpine-scrubland:scrubland 4.169423e-05 -4.243753e-04 0.0005077637
# subalpine:pineoak-scrubland:scrubland   5.356605e-05 -4.125035e-04 0.0005196355
# pineoak:pineoak-scrubland:scrubland     6.349624e-05 -4.025733e-04 0.0005295657
# grassland:subalpine-scrubland:scrubland 8.482481e-05 -3.812447e-04 0.0005508943
# scrubland:subalpine-scrubland:scrubland 9.570334e-05 -3.703662e-04 0.0005617728
# grassland:pineoak-scrubland:scrubland   1.039640e-04 -3.621055e-04 0.0005700335
# subalpine:scrubland-scrubland:scrubland 1.083045e-04 -3.577650e-04 0.0005743740
# pineoak:scrubland-scrubland:scrubland   1.096832e-04 -3.563863e-04 0.0005757527
# scrubland:pineoak-scrubland:scrubland   1.551114e-04 -3.109581e-04 0.0006211809
# pineoak:subalpine-grassland:scrubland   4.570905e-06 -4.614986e-04 0.0004706404
# subalpine:subalpine-grassland:scrubland 1.653293e-05 -4.495366e-04 0.0004826024
# subalpine:pineoak-grassland:scrubland   2.840475e-05 -4.376647e-04 0.0004944743
# pineoak:pineoak-grassland:scrubland     3.833494e-05 -4.277346e-04 0.0005044044
# grassland:subalpine-grassland:scrubland 5.966351e-05 -4.064060e-04 0.0005257330
# scrubland:subalpine-grassland:scrubland 7.054205e-05 -3.955274e-04 0.0005366116
# grassland:pineoak-grassland:scrubland   7.880271e-05 -3.872668e-04 0.0005448722
# subalpine:scrubland-grassland:scrubland 8.314318e-05 -3.829263e-04 0.0005492127
# pineoak:scrubland-grassland:scrubland   8.452187e-05 -3.815476e-04 0.0005505914
# scrubland:pineoak-grassland:scrubland   1.299501e-04 -3.361194e-04 0.0005960196
# subalpine:subalpine-pineoak:subalpine   1.196203e-05 -4.541075e-04 0.0004780315
# subalpine:pineoak-pineoak:subalpine     2.383385e-05 -4.422356e-04 0.0004899033
# pineoak:pineoak-pineoak:subalpine       3.376404e-05 -4.323055e-04 0.0004998335
# grassland:subalpine-pineoak:subalpine   5.509261e-05 -4.109769e-04 0.0005211621
# scrubland:subalpine-pineoak:subalpine   6.597115e-05 -4.000983e-04 0.0005320406
# grassland:pineoak-pineoak:subalpine     7.423181e-05 -3.918377e-04 0.0005403013
# subalpine:scrubland-pineoak:subalpine   7.857228e-05 -3.874972e-04 0.0005446418
# pineoak:scrubland-pineoak:subalpine     7.995097e-05 -3.861185e-04 0.0005460205
# scrubland:pineoak-pineoak:subalpine     1.253792e-04 -3.406903e-04 0.0005914487
# subalpine:pineoak-subalpine:subalpine   1.187182e-05 -4.541977e-04 0.0004779413
# pineoak:pineoak-subalpine:subalpine     2.180201e-05 -4.442675e-04 0.0004878715
# grassland:subalpine-subalpine:subalpine 4.313058e-05 -4.229389e-04 0.0005092001
# scrubland:subalpine-subalpine:subalpine 5.400912e-05 -4.120604e-04 0.0005200786
# grassland:pineoak-subalpine:subalpine   6.226978e-05 -4.037997e-04 0.0005283393
# subalpine:scrubland-subalpine:subalpine 6.661025e-05 -3.994593e-04 0.0005326797
# pineoak:scrubland-subalpine:subalpine   6.798893e-05 -3.980806e-04 0.0005340584
# scrubland:pineoak-subalpine:subalpine   1.134172e-04 -3.526523e-04 0.0005794867
# pineoak:pineoak-subalpine:pineoak       9.930190e-06 -4.561393e-04 0.0004759997
# grassland:subalpine-subalpine:pineoak   3.125876e-05 -4.348107e-04 0.0004973283
# scrubland:subalpine-subalpine:pineoak   4.213730e-05 -4.239322e-04 0.0005082068
# grassland:pineoak-subalpine:pineoak     5.039796e-05 -4.156715e-04 0.0005164675
# subalpine:scrubland-subalpine:pineoak   5.473842e-05 -4.113311e-04 0.0005208079
# pineoak:scrubland-subalpine:pineoak     5.611711e-05 -4.099524e-04 0.0005221866
# scrubland:pineoak-subalpine:pineoak     1.015453e-04 -3.645242e-04 0.0005676148
# grassland:subalpine-pineoak:pineoak     2.132857e-05 -4.447409e-04 0.0004873981
# scrubland:subalpine-pineoak:pineoak     3.220711e-05 -4.338624e-04 0.0004982766
# grassland:pineoak-pineoak:pineoak       4.046777e-05 -4.256017e-04 0.0005065373
# subalpine:scrubland-pineoak:pineoak     4.480824e-05 -4.212613e-04 0.0005108777
# pineoak:scrubland-pineoak:pineoak       4.618692e-05 -4.198826e-04 0.0005122564
# scrubland:pineoak-pineoak:pineoak       9.161515e-05 -3.744543e-04 0.0005576846
# scrubland:subalpine-grassland:subalpine 1.087854e-05 -4.551910e-04 0.0004769480
# grassland:pineoak-grassland:subalpine   1.913920e-05 -4.469303e-04 0.0004852087
# subalpine:scrubland-grassland:subalpine 2.347967e-05 -4.425898e-04 0.0004895492
# pineoak:scrubland-grassland:subalpine   2.485835e-05 -4.412111e-04 0.0004909279
# scrubland:pineoak-grassland:subalpine   7.028658e-05 -3.957829e-04 0.0005363561
# grassland:pineoak-scrubland:subalpine   8.260655e-06 -4.578088e-04 0.0004743302
# subalpine:scrubland-scrubland:subalpine 1.260113e-05 -4.534684e-04 0.0004786706
# pineoak:scrubland-scrubland:subalpine   1.397982e-05 -4.520897e-04 0.0004800493
# scrubland:pineoak-scrubland:subalpine   5.940804e-05 -4.066615e-04 0.0005254775
# subalpine:scrubland-grassland:pineoak   4.340470e-06 -4.617290e-04 0.0004704100
# pineoak:scrubland-grassland:pineoak     5.719160e-06 -4.603503e-04 0.0004717887
# scrubland:pineoak-grassland:pineoak     5.114738e-05 -4.149221e-04 0.0005172169
# pineoak:scrubland-subalpine:scrubland   1.378690e-06 -4.646908e-04 0.0004674482
# scrubland:pineoak-subalpine:scrubland   4.680691e-05 -4.192626e-04 0.0005128764
# scrubland:pineoak-pineoak:scrubland     4.542822e-05 -4.206413e-04 0.0005114977
#                                             p adj
# desert:scrubland-desert:desert          1.0000000
# desert:grassland-desert:desert          1.0000000
# grassland:desert-desert:desert          0.9999983
# scrubland:desert-desert:desert          0.9999962
# desert:subalpine-desert:desert          0.9999689
# desert:pineoak-desert:desert            0.9966599
# subalpine:desert-desert:desert          0.9699363
# pineoak:desert-desert:desert            0.9541977
# grassland:grassland-desert:desert       0.8897586
# subalpine:grassland-desert:desert       0.8609869
# pineoak:grassland-desert:desert         0.8297479
# scrubland:grassland-desert:desert       0.8293726
# scrubland:scrubland-desert:desert       0.7871298
# grassland:scrubland-desert:desert       0.6431685
# pineoak:subalpine-desert:desert         0.6147382
# subalpine:subalpine-desert:desert       0.5392551
# subalpine:pineoak-desert:desert         0.4649719
# pineoak:pineoak-desert:desert           0.4051217
# grassland:subalpine-desert:desert       0.2890629
# scrubland:subalpine-desert:desert       0.2382468
# grassland:pineoak-desert:desert         0.2038299
# subalpine:scrubland-desert:desert       0.1872032
# pineoak:scrubland-desert:desert         0.1821307
# scrubland:pineoak-desert:desert         0.0658102
# desert:grassland-desert:scrubland       1.0000000
# grassland:desert-desert:scrubland       1.0000000
# scrubland:desert-desert:scrubland       1.0000000
# desert:subalpine-desert:scrubland       1.0000000
# desert:pineoak-desert:scrubland         0.9999979
# subalpine:desert-desert:scrubland       0.9997911
# pineoak:desert-desert:scrubland         0.9994925
# grassland:grassland-desert:scrubland    0.9966671
# subalpine:grassland-desert:scrubland    0.9944628
# pineoak:grassland-desert:scrubland      0.9913235
# scrubland:grassland-desert:scrubland    0.9912808
# scrubland:scrubland-desert:scrubland    0.9856648
# grassland:scrubland-desert:scrubland    0.9523267
# pineoak:subalpine-desert:scrubland      0.9426367
# subalpine:subalpine-desert:scrubland    0.9107974
# subalpine:pineoak-desert:scrubland      0.8693016
# pineoak:pineoak-desert:scrubland        0.8269524
# grassland:subalpine-desert:scrubland    0.7152583
# scrubland:subalpine-desert:scrubland    0.6501940
# grassland:pineoak-desert:scrubland      0.5987348
# subalpine:scrubland-desert:scrubland    0.5713417
# pineoak:scrubland-desert:scrubland      0.5626202
# scrubland:pineoak-desert:scrubland      0.2960222
# grassland:desert-desert:grassland       1.0000000
# scrubland:desert-desert:grassland       1.0000000
# desert:subalpine-desert:grassland       1.0000000
# desert:pineoak-desert:grassland         1.0000000
# subalpine:desert-desert:grassland       0.9999956
# pineoak:desert-desert:grassland         0.9999847
# grassland:grassland-desert:grassland    0.9997863
# subalpine:grassland-desert:grassland    0.9995646
# pineoak:grassland-desert:grassland      0.9991819
# scrubland:grassland-desert:grassland    0.9991763
# scrubland:scrubland-desert:grassland    0.9983419
# grassland:scrubland-desert:grassland    0.9908992
# pineoak:subalpine-desert:grassland      0.9881441
# subalpine:subalpine-desert:grassland    0.9776348
# subalpine:pineoak-desert:grassland      0.9610651
# pineoak:pineoak-desert:grassland        0.9412464
# grassland:subalpine-desert:grassland    0.8766046
# scrubland:subalpine-desert:grassland    0.8312858
# grassland:pineoak-desert:grassland      0.7915763
# subalpine:scrubland-desert:grassland    0.7690458
# pineoak:scrubland-desert:grassland      0.7616684
# scrubland:pineoak-desert:grassland      0.4853589
# scrubland:desert-grassland:desert       1.0000000
# desert:subalpine-grassland:desert       1.0000000
# desert:pineoak-grassland:desert         1.0000000
# subalpine:desert-grassland:desert       0.9999999
# pineoak:desert-grassland:desert         0.9999997
# grassland:grassland-grassland:desert    0.9999896
# subalpine:grassland-grassland:desert    0.9999734
# pineoak:grassland-grassland:desert      0.9999389
# scrubland:grassland-grassland:desert    0.9999384
# scrubland:scrubland-grassland:desert    0.9998454
# grassland:scrubland-grassland:desert    0.9985477
# pineoak:subalpine-grassland:desert      0.9979413
# subalpine:subalpine-grassland:desert    0.9952336
# subalpine:pineoak-grassland:desert      0.9900414
# pineoak:pineoak-grassland:desert        0.9827420
# grassland:subalpine-grassland:desert    0.9530432
# scrubland:subalpine-grassland:desert    0.9280288
# grassland:pineoak-grassland:desert      0.9037294
# subalpine:scrubland-grassland:desert    0.8890312
# pineoak:scrubland-grassland:desert      0.8840808
# scrubland:pineoak-grassland:desert      0.6539971
# desert:subalpine-scrubland:desert       1.0000000
# desert:pineoak-scrubland:desert         1.0000000
# subalpine:desert-scrubland:desert       1.0000000
# pineoak:desert-scrubland:desert         0.9999999
# grassland:grassland-scrubland:desert    0.9999950
# subalpine:grassland-scrubland:desert    0.9999865
# pineoak:grassland-scrubland:desert      0.9999675
# scrubland:grassland-scrubland:desert    0.9999672
# scrubland:scrubland-scrubland:desert    0.9999132
# grassland:scrubland-scrubland:desert    0.9990710
# pineoak:subalpine-scrubland:desert      0.9986561
# subalpine:subalpine-scrubland:desert    0.9967317
# subalpine:pineoak-scrubland:desert      0.9928670
# pineoak:pineoak-scrubland:desert        0.9872236
# grassland:subalpine-scrubland:desert    0.9630236
# scrubland:subalpine-scrubland:desert    0.9417601
# grassland:pineoak-scrubland:desert      0.9206025
# subalpine:scrubland-scrubland:desert    0.9076128
# pineoak:scrubland-scrubland:desert      0.9032091
# scrubland:pineoak-scrubland:desert      0.6876349
# desert:pineoak-desert:subalpine         1.0000000
# subalpine:desert-desert:subalpine       1.0000000
# pineoak:desert-desert:subalpine         1.0000000
# grassland:grassland-desert:subalpine    0.9999996
# subalpine:grassland-desert:subalpine    0.9999986
# pineoak:grassland-desert:subalpine      0.9999960
# scrubland:grassland-desert:subalpine    0.9999959
# scrubland:scrubland-desert:subalpine    0.9999870
# grassland:scrubland-desert:subalpine    0.9997863
# pineoak:subalpine-desert:subalpine      0.9996696
# subalpine:subalpine-desert:subalpine    0.9990563
# subalpine:pineoak-desert:subalpine      0.9976256
# pineoak:pineoak-desert:subalpine        0.9952648
# grassland:subalpine-desert:subalpine    0.9832553
# scrubland:subalpine-desert:subalpine    0.9711888
# grassland:pineoak-desert:subalpine      0.9582251
# subalpine:scrubland-desert:subalpine    0.9498795
# pineoak:scrubland-desert:subalpine      0.9469903
# scrubland:pineoak-desert:subalpine      0.7793917
# subalpine:desert-desert:pineoak         1.0000000
# pineoak:desert-desert:pineoak           1.0000000
# grassland:grassland-desert:pineoak      1.0000000
# subalpine:grassland-desert:pineoak      1.0000000
# pineoak:grassland-desert:pineoak        1.0000000
# scrubland:grassland-desert:pineoak      1.0000000
# scrubland:scrubland-desert:pineoak      1.0000000
# grassland:scrubland-desert:pineoak      0.9999997
# pineoak:subalpine-desert:pineoak        0.9999994
# subalpine:subalpine-desert:pineoak      0.9999963
# subalpine:pineoak-desert:pineoak        0.9999825
# pineoak:pineoak-desert:pineoak          0.9999441
# grassland:subalpine-desert:pineoak      0.9995279
# scrubland:subalpine-desert:pineoak      0.9988126
# grassland:pineoak-desert:pineoak        0.9977589
# subalpine:scrubland-desert:pineoak      0.9969356
# pineoak:scrubland-desert:pineoak        0.9966251
# scrubland:pineoak-desert:pineoak        0.9582927
# pineoak:desert-subalpine:desert         1.0000000
# grassland:grassland-subalpine:desert    1.0000000
# subalpine:grassland-subalpine:desert    1.0000000
# pineoak:grassland-subalpine:desert      1.0000000
# scrubland:grassland-subalpine:desert    1.0000000
# scrubland:scrubland-subalpine:desert    1.0000000
# grassland:scrubland-subalpine:desert    1.0000000
# pineoak:subalpine-subalpine:desert      1.0000000
# subalpine:subalpine-subalpine:desert    1.0000000
# subalpine:pineoak-subalpine:desert      0.9999999
# pineoak:pineoak-subalpine:desert        0.9999997
# grassland:subalpine-subalpine:desert    0.9999929
# scrubland:subalpine-subalpine:desert    0.9999721
# grassland:pineoak-subalpine:desert      0.9999287
# subalpine:scrubland-subalpine:desert    0.9998868
# pineoak:scrubland-subalpine:desert      0.9998695
# scrubland:pineoak-subalpine:desert      0.9945453
# grassland:grassland-pineoak:desert      1.0000000
# subalpine:grassland-pineoak:desert      1.0000000
# pineoak:grassland-pineoak:desert        1.0000000
# scrubland:grassland-pineoak:desert      1.0000000
# scrubland:scrubland-pineoak:desert      1.0000000
# grassland:scrubland-pineoak:desert      1.0000000
# pineoak:subalpine-pineoak:desert        1.0000000
# subalpine:subalpine-pineoak:desert      1.0000000
# subalpine:pineoak-pineoak:desert        1.0000000
# pineoak:pineoak-pineoak:desert          0.9999999
# grassland:subalpine-pineoak:desert      0.9999981
# scrubland:subalpine-pineoak:desert      0.9999915
# grassland:pineoak-pineoak:desert        0.9999760
# subalpine:scrubland-pineoak:desert      0.9999600
# pineoak:scrubland-pineoak:desert        0.9999532
# scrubland:pineoak-pineoak:desert        0.9971402
# subalpine:grassland-grassland:grassland 1.0000000
# pineoak:grassland-grassland:grassland   1.0000000
# scrubland:grassland-grassland:grassland 1.0000000
# scrubland:scrubland-grassland:grassland 1.0000000
# grassland:scrubland-grassland:grassland 1.0000000
# pineoak:subalpine-grassland:grassland   1.0000000
# subalpine:subalpine-grassland:grassland 1.0000000
# subalpine:pineoak-grassland:grassland   1.0000000
# pineoak:pineoak-grassland:grassland     1.0000000
# grassland:subalpine-grassland:grassland 1.0000000
# scrubland:subalpine-grassland:grassland 0.9999998
# grassland:pineoak-grassland:grassland   0.9999991
# subalpine:scrubland-grassland:grassland 0.9999982
# pineoak:scrubland-grassland:grassland   0.9999978
# scrubland:pineoak-grassland:grassland   0.9995825
# pineoak:grassland-subalpine:grassland   1.0000000
# scrubland:grassland-subalpine:grassland 1.0000000
# scrubland:scrubland-subalpine:grassland 1.0000000
# grassland:scrubland-subalpine:grassland 1.0000000
# pineoak:subalpine-subalpine:grassland   1.0000000
# subalpine:subalpine-subalpine:grassland 1.0000000
# subalpine:pineoak-subalpine:grassland   1.0000000
# pineoak:pineoak-subalpine:grassland     1.0000000
# grassland:subalpine-subalpine:grassland 1.0000000
# scrubland:subalpine-subalpine:grassland 0.9999999
# grassland:pineoak-subalpine:grassland   0.9999997
# subalpine:scrubland-subalpine:grassland 0.9999994
# pineoak:scrubland-subalpine:grassland   0.9999993
# scrubland:pineoak-subalpine:grassland   0.9997958
# scrubland:grassland-pineoak:grassland   1.0000000
# scrubland:scrubland-pineoak:grassland   1.0000000
# grassland:scrubland-pineoak:grassland   1.0000000
# pineoak:subalpine-pineoak:grassland     1.0000000
# subalpine:subalpine-pineoak:grassland   1.0000000
# subalpine:pineoak-pineoak:grassland     1.0000000
# pineoak:pineoak-pineoak:grassland       1.0000000
# grassland:subalpine-pineoak:grassland   1.0000000
# scrubland:subalpine-pineoak:grassland   1.0000000
# grassland:pineoak-pineoak:grassland     0.9999999
# subalpine:scrubland-pineoak:grassland   0.9999998
# pineoak:scrubland-pineoak:grassland     0.9999998
# scrubland:pineoak-pineoak:grassland     0.9999022
# scrubland:scrubland-scrubland:grassland 1.0000000
# grassland:scrubland-scrubland:grassland 1.0000000
# pineoak:subalpine-scrubland:grassland   1.0000000
# subalpine:subalpine-scrubland:grassland 1.0000000
# subalpine:pineoak-scrubland:grassland   1.0000000
# pineoak:pineoak-scrubland:grassland     1.0000000
# grassland:subalpine-scrubland:grassland 1.0000000
# scrubland:subalpine-scrubland:grassland 1.0000000
# grassland:pineoak-scrubland:grassland   0.9999999
# subalpine:scrubland-scrubland:grassland 0.9999998
# pineoak:scrubland-scrubland:grassland   0.9999998
# scrubland:pineoak-scrubland:grassland   0.9999031
# grassland:scrubland-scrubland:scrubland 1.0000000
# pineoak:subalpine-scrubland:scrubland   1.0000000
# subalpine:subalpine-scrubland:scrubland 1.0000000
# subalpine:pineoak-scrubland:scrubland   1.0000000
# pineoak:pineoak-scrubland:scrubland     1.0000000
# grassland:subalpine-scrubland:scrubland 1.0000000
# scrubland:subalpine-scrubland:scrubland 1.0000000
# grassland:pineoak-scrubland:scrubland   1.0000000
# subalpine:scrubland-scrubland:scrubland 1.0000000
# pineoak:scrubland-scrubland:scrubland   1.0000000
# scrubland:pineoak-scrubland:scrubland   0.9999630
# pineoak:subalpine-grassland:scrubland   1.0000000
# subalpine:subalpine-grassland:scrubland 1.0000000
# subalpine:pineoak-grassland:scrubland   1.0000000
# pineoak:pineoak-grassland:scrubland     1.0000000
# grassland:subalpine-grassland:scrubland 1.0000000
# scrubland:subalpine-grassland:scrubland 1.0000000
# grassland:pineoak-grassland:scrubland   1.0000000
# subalpine:scrubland-grassland:scrubland 1.0000000
# pineoak:scrubland-grassland:scrubland   1.0000000
# scrubland:pineoak-grassland:scrubland   0.9999987
# subalpine:subalpine-pineoak:subalpine   1.0000000
# subalpine:pineoak-pineoak:subalpine     1.0000000
# pineoak:pineoak-pineoak:subalpine       1.0000000
# grassland:subalpine-pineoak:subalpine   1.0000000
# scrubland:subalpine-pineoak:subalpine   1.0000000
# grassland:pineoak-pineoak:subalpine     1.0000000
# subalpine:scrubland-pineoak:subalpine   1.0000000
# pineoak:scrubland-pineoak:subalpine     1.0000000
# scrubland:pineoak-pineoak:subalpine     0.9999993
# subalpine:pineoak-subalpine:subalpine   1.0000000
# pineoak:pineoak-subalpine:subalpine     1.0000000
# grassland:subalpine-subalpine:subalpine 1.0000000
# scrubland:subalpine-subalpine:subalpine 1.0000000
# grassland:pineoak-subalpine:subalpine   1.0000000
# subalpine:scrubland-subalpine:subalpine 1.0000000
# pineoak:scrubland-subalpine:subalpine   1.0000000
# scrubland:pineoak-subalpine:subalpine   0.9999999
# pineoak:pineoak-subalpine:pineoak       1.0000000
# grassland:subalpine-subalpine:pineoak   1.0000000
# scrubland:subalpine-subalpine:pineoak   1.0000000
# grassland:pineoak-subalpine:pineoak     1.0000000
# subalpine:scrubland-subalpine:pineoak   1.0000000
# pineoak:scrubland-subalpine:pineoak     1.0000000
# scrubland:pineoak-subalpine:pineoak     1.0000000
# grassland:subalpine-pineoak:pineoak     1.0000000
# scrubland:subalpine-pineoak:pineoak     1.0000000
# grassland:pineoak-pineoak:pineoak       1.0000000
# subalpine:scrubland-pineoak:pineoak     1.0000000
# pineoak:scrubland-pineoak:pineoak       1.0000000
# scrubland:pineoak-pineoak:pineoak       1.0000000
# scrubland:subalpine-grassland:subalpine 1.0000000
# grassland:pineoak-grassland:subalpine   1.0000000
# subalpine:scrubland-grassland:subalpine 1.0000000
# pineoak:scrubland-grassland:subalpine   1.0000000
# scrubland:pineoak-grassland:subalpine   1.0000000
# grassland:pineoak-scrubland:subalpine   1.0000000
# subalpine:scrubland-scrubland:subalpine 1.0000000
# pineoak:scrubland-scrubland:subalpine   1.0000000
# scrubland:pineoak-scrubland:subalpine   1.0000000
# subalpine:scrubland-grassland:pineoak   1.0000000
# pineoak:scrubland-grassland:pineoak     1.0000000
# scrubland:pineoak-grassland:pineoak     1.0000000
# pineoak:scrubland-subalpine:scrubland   1.0000000
# scrubland:pineoak-subalpine:scrubland   1.0000000
# scrubland:pineoak-pineoak:scrubland     1.0000000

# %%
# last day of the last year
enz_data_d2 <- data_anova(enz_data,1+365*4 + 365*4 - 1)
head(enz_data_d2)
# Out:
#    origin site   decom
# X0 desert desert 0.0015693954
# X1 desert desert 0.0021875966
# X2 desert desert 0.0010842525
# X3 desert desert 0.0005521731
# X4 desert desert 0.0013245111
# X5 desert desert 0.0018966636

# %%
enz_fit_d2 <- aov(decom ~ origin + site + origin:site, data=enz_data_d2)
summary(enz_fit_d2)
# Out:
#              Df    Sum Sq   Mean Sq F value   Pr(>F)
# origin        4 1.100e-06 2.754e-07   1.511    0.198
# site          4 7.210e-06 1.802e-06   9.882 1.09e-07 ***
# origin:site  16 4.600e-07 2.870e-08   0.157    1.000
# Residuals   475 8.659e-05 1.823e-07
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
cat('Contribution by each factor:',summary(enz_fit_d2)[[1]]$'Sum Sq'/sum(summary(enz_fit_d2)[[1]]$'Sum Sq'))
# Out:
# Contribution by each factor: 0.01155115 0.07556813 0.004811448 0.9080693

# %%
## drought tolerance
#create file list and read the decomposition data into a list
file_list <- list()
for (i in 1:25){
    site=c('desert','scrubland','grassland','pineoak','subalpine')
    name<-data.frame(origin=rep(site,times=1,each=5),site=rep(site,times=5,each=1))

    file_list[i] = paste(name$origin[i],"/","Drt_",name$origin[i],"_",name$site[i],'.csv',sep="")
}
drt_data <- lapply(file_list,function(path)read.csv(path,row.names=1))

# %%
# last day of the first year
drt_data_d1 <- data_anova(drt_data,1+365*4 + 365 - 1)
head(drt_data_d1)
# Out:
#    origin site   decom
# X0 desert desert 0.9641955
# X1 desert desert 0.8851461
# X2 desert desert 0.9636836
# X3 desert desert 0.9150863
# X4 desert desert 0.9106528
# X5 desert desert 0.9010322

# %%
drt_fit_d1 <- aov(decom ~ origin + site + origin:site, data=drt_data_d1)
summary(drt_fit_d1)
# Out:
#              Df Sum Sq Mean Sq F value Pr(>F)
# origin        4  7.224  1.8061   323.9 <2e-16 ***
# site          4  5.636  1.4089   252.7 <2e-16 ***
# origin:site  16  1.071  0.0669    12.0 <2e-16 ***
# Residuals   475  2.649  0.0056
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
cat('Contribution by each factor:',summary(drt_fit_d1)[[1]]$'Sum Sq'/sum(summary(drt_fit_d1)[[1]]$'Sum Sq'))
# Out:
# Contribution by each factor: 0.4357417 0.3399117 0.06458667 0.15976

# %%
# last day of the last year
drt_data_d2 <- data_anova(drt_data,1+365*4 + 365*4 - 1)
head(drt_data_d2)
# Out:
#    origin site   decom
# X0 desert desert 0.9723694
# X1 desert desert 0.8845438
# X2 desert desert 0.9636903
# X3 desert desert 0.9141868
# X4 desert desert 0.9155219
# X5 desert desert 0.9099207

# %%
drt_fit_d2 <- aov(decom ~ origin + site + origin:site, data=drt_data_d2)
summary(drt_fit_d2)
# Out:
#              Df Sum Sq Mean Sq F value Pr(>F)
# origin        4  3.583  0.8957  159.99 <2e-16 ***
# site          4 11.504  2.8759  513.68 <2e-16 ***
# origin:site  16  1.672  0.1045   18.67 <2e-16 ***
# Residuals   475  2.659  0.0056
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
cat('Contribution by each factor:',summary(drt_fit_d2)[[1]]$'Sum Sq'/sum(summary(drt_fit_d2)[[1]]$'Sum Sq'))
# Out:
# Contribution by each factor: 0.1845083 0.5924159 0.08612304 0.1369528

# %% [markdown]
# #### 2.3 Multiple Linear Regression of decomposition against trait and environment
#
# A multiple linear regression and model selection performed on data of different days.
#
# ---
#
# **R implementation**:
#
# Interaction Effect in Multiple Regression: Essentials: http://www.sthda.com/english/articles/40-regression-analysis/164-interaction-effect-in-multiple-regression-essentials/
#
# Interactions in multiple linear regression: https://medium.com/@dkatzman_3920/interactions-in-multiple-linear-regression-9f735b12826b

# %%
#create file list and read the climate data into a list
file_list <- list()
for (i in 1:5){
    site=c('desert','scrubland','grassland','pineoak','subalpine')
    #name<-data.frame(origin=rep(site,times=1,each=1),site=rep(site,times=1,each=1))
    name<-rep(site,times=1,each=1)

    #file_list[i] = paste(name$origin[i],"/v1/","Sub_",name$origin[i],"_",name$site[i],'.csv',sep="")
    file_list[i] = paste("../../../inputs/",name[i],'/','climate.csv',sep="")
}
#climate_data <- lapply(file_list,function(path)read.csv(path,row.names=1))

# annual mean
climate_data <- lapply(file_list,function(path)colMeans(read.csv(path,row.names=1)))

# %%
climate_data
# Out:
# [[1]]
#      Temp       Psi
# 26.268447 -5.304724
#
# [[2]]
#     Temp      Psi
# 17.38935 -3.63366
#
# [[3]]
#      Temp       Psi
# 18.869704 -2.343992
#
# [[4]]
#      Temp       Psi
# 11.277296 -1.185888
#
# [[5]]
#      Temp       Psi
# 10.912715 -1.487242

# %%
#define a function of obtaining data of any day
# data_climate <- function(climate_data,day){
    
#     climate_data_fr <- do.call("cbind.data.frame", climate_data)
#     data_climate <- climate_data_fr[as.character(day),]
#     #colnames(data_climate) = c('temp','psi')
    
#     rsp_climate<-rbind(data_climate[,c(1,2)],data_climate[,c(3,4)],
#                    data_climate[,c(5,6)],data_climate[,c(7,8)],
#                    data_climate[,c(9,10)])
    
#     #data_climate<-rsp_climate[rep(2, 20), ]
#     climate_data<-rsp_climate[rep(seq_len(nrow(rsp_climate)), each = 20), ]
#     #rsp_climate[rep(seq_len(nrow(rsp_climate)), each = 20), ]
#     rownames(climate_data) <- c()

#     climate_data
# }

### 
data_climate <- function(climate_data){
    
    climate_data_fr <- do.call("cbind.data.frame", climate_data)
    data_climate <- climate_data_fr[,]
    #colnames(data_climate) = c('temp','psi')
    
    rsp_climate<-rbind(data_climate[,1],data_climate[,2],
                   data_climate[,3],data_climate[,4],
                   data_climate[,5])
    
    #data_climate<-rsp_climate[rep(2, 20), ]
    climate_data<-rsp_climate[rep(seq_len(nrow(rsp_climate)), each = 20), ]
    #rsp_climate[rep(seq_len(nrow(rsp_climate)), each = 20), ]
    colnames(climate_data) <- c('Temp','Psi')

    climate_data
}

# %%
#create file list and read the source biomass data into a list
file_list <- list()
for (i in 1:25){
    site=c('desert','scrubland','grassland','pineoak','subalpine')
    name<-data.frame(origin=rep(site,times=1,each=5),site=rep(site,times=5,each=1))

    file_list[i] = paste(name$origin[i],"/","Mic_",name$origin[i],"_",name$site[i],'.csv',sep="")
}
mic_data <- lapply(file_list,function(path)read.csv(path,row.names=1))

# %%
res <- cor(data_sub_d1$decom, data_anova(mic_data,1+365*4 + 200)$decom, method = "pearson")
cat('R=',res)
# Out:
# Error in is.data.frame(x): object 'data_sub_d1' not found
# Traceback:
#
# 1. cor(data_sub_d1$decom, data_anova(mic_data, 1 + 365 * 4 + 200)$decom,
#  .     method = "pearson")
# 2. is.data.frame(x)

# %%
plot(data_sub_d1$decom, data_anova(mic_data,1+365*4 + 1)$decom)
# Out:
# Error in plot(data_sub_d1$decom, data_anova(mic_data, 1 + 365 * 4 + 1)$decom): object 'data_sub_d1' not found
# Traceback:
#
# 1. plot(data_sub_d1$decom, data_anova(mic_data, 1 + 365 * 4 + 1)$decom)

# %% [markdown]
# #### First year
#
# - with local environment of the last day
#
# - with local env of the max in a year
#
# - with local env averged across the whole year

# %%
# environment of the last day 
data_climate_d1 <- data_climate(climate_data,200)

data_sub_d1 <- data_anova(sub_data,1+365*4 + 365 - 1)
data_sub_d1[,'decom'] <- data_sub_d1$decom/10000
# day 1
data_enz_d1 <- data_anova(enz_data,1+365*4 + 365 - 1) # last day
data_drt_d1 <- data_anova(drt_data,1+365*4 + 365 - 1) # last day

# concatenate the same day climate and decomposition and traits (last day of the 1st year)
# into one dataframe
all_data_d1 <- cbind(data_sub_d1,data_climate_d1, data_enz_d1$decom,data_drt_d1$decom)
names(all_data_d1)[6] <- 'Enz'
names(all_data_d1)[7] <- 'Drt'
head(all_data_d1)
# Out:
#    origin site   decom    Temp     Psi       Enz          Drt
# X0 desert desert 260.4377 38.51389 -8.498463 0.0016435153 0.9641955
# X1 desert desert 259.2960 38.51389 -8.498463 0.0021950307 0.8851461
# X2 desert desert 289.8874 38.51389 -8.498463 0.0011091144 0.9636836
# X3 desert desert 309.1437 38.51389 -8.498463 0.0005713315 0.9150863
# X4 desert desert 255.3615 38.51389 -8.498463 0.0013090709 0.9106528
# X5 desert desert 263.3692 38.51389 -8.498463 0.0019363400 0.9010322

# %%
# model 1 w/ only Temp & Psi
mod1_d1 <- lm(decom ~ Temp + Psi, data=all_data_d1)
summary(mod1_d1)
# Out:
# Call:
# lm(formula = decom ~ Temp + Psi, data = all_data_d1)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -102.35  -47.35  -10.13   38.60  197.59
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  246.053     54.191   4.540 7.05e-06 ***
# Temp          -8.601      2.718  -3.165  0.00165 **
# Psi          -38.334      5.914  -6.482 2.18e-10 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 62.51 on 497 degrees of freedom
# Multiple R-squared:  0.4409,	Adjusted R-squared:  0.4386
# F-statistic:   196 on 2 and 497 DF,  p-value: < 2.2e-16

# %%
AIC(mod1_d1)
BIC(mod1_d1)
# Out:
# [1] 5559.237
# [1] 5576.096

# %%
mod2_d1 <- lm(decom ~ Temp + Psi + Enz, data=all_data_d1)
summary(mod2_d1)
# Out:
# Call:
# lm(formula = decom ~ Temp + Psi + Enz, data = all_data_d1)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -114.140  -35.540   -5.425   32.212  161.913
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)    476.897     47.710   9.996  < 2e-16 ***
# Temp           -11.555      2.271  -5.088 5.14e-07 ***
# Psi            -42.775      4.932  -8.672  < 2e-16 ***
# Enz         -86180.275   5795.531 -14.870  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 52.04 on 496 degrees of freedom
# Multiple R-squared:  0.6133,	Adjusted R-squared:  0.6109
# F-statistic: 262.2 on 3 and 496 DF,  p-value: < 2.2e-16

# %%
AIC(mod2_d1)
BIC(mod2_d1)
# Out:
# [1] 5376.903
# [1] 5397.976

# %%
# model 3 with Drt instead of Enz
mod3_d1 <- lm(decom ~ Temp + Psi + Drt, data=all_data_d1)
summary(mod3_d1)
# Out:
# Call:
# lm(formula = decom ~ Temp + Psi + Drt, data = all_data_d1)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -122.519  -41.116   -0.665   37.660  131.330
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   66.055     46.656   1.416   0.1575
# Temp          -5.629      2.269  -2.481   0.0134 *
# Psi          -23.125      5.023  -4.604 5.28e-06 ***
# Drt          233.056     15.622  14.918  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 51.99 on 496 degrees of freedom
# Multiple R-squared:  0.6141,	Adjusted R-squared:  0.6117
# F-statistic: 263.1 on 3 and 496 DF,  p-value: < 2.2e-16

# %%
AIC(mod3_d1)
BIC(mod3_d1)
# Out:
# [1] 5375.903
# [1] 5396.976

# %%
# Model 4 plus drought trait
mod4_d1 <- lm(decom ~ Temp + Psi + Enz + Drt, data=all_data_d1)
summary(mod4_d1)
# Out:
# Call:
# lm(formula = decom ~ Temp + Psi + Enz + Drt, data = all_data_d1)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -108.501  -31.539   -2.246   30.778  109.074
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)    285.438     43.912   6.500 1.96e-10 ***
# Temp            -8.583      1.981  -4.334 1.78e-05 ***
# Psi            -29.920      4.387  -6.820 2.66e-11 ***
# Enz         -67172.126   5231.817 -12.839  < 2e-16 ***
# Drt            181.972     14.117  12.891  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 45.07 on 495 degrees of freedom
# Multiple R-squared:  0.7105,	Adjusted R-squared:  0.7081
# F-statistic: 303.7 on 4 and 495 DF,  p-value: < 2.2e-16

# %%
AIC(mod4_d1)
BIC(mod4_d1)
# Out:
# [1] 5234.18
# [1] 5259.468

# %%
plot(all_data_d1$Enz, all_data_d1$decom)
plot(all_data_d1$Drt, all_data_d1$decom)
# Out:
# plot without title
# plot without title

# %%
#### drought and enzyme traits of the first day 
data_climate_d2 <- data_climate(climate_data,200)

data_sub_d2 <- data_anova(sub_data,1+365*4 + 365 - 1)
data_sub_d2[,'decom'] <- data_sub_d2$decom/10000
data_enz_d2 <- data_anova(enz_data,1+365*4 + 1) # first day
data_drt_d2 <- data_anova(drt_data,1+365*4 + 1) # first day


# concatenate the same day climate and decomposition and traits (last day of the 1st year)
# into one dataframe
all_data_d2 <- cbind(data_sub_d2,data_climate_d2, data_enz_d2$decom,data_drt_d2$decom)
names(all_data_d2)[6] <- 'Enz'
names(all_data_d2)[7] <- 'Drt'

head(all_data_d2)
# Out:
# Error in data_climate(climate_data, 200): unused argument (200)
# Traceback:

# %%
# Model 1
mod1_d2 <- lm(decom ~ Temp + Psi, data=all_data_d2)
summary(mod1_d2)
# Out:
# Call:
# lm(formula = decom ~ Temp + Psi, data = all_data_d2)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -102.35  -47.35  -10.13   38.60  197.59
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  246.053     54.191   4.540 7.05e-06 ***
# Temp          -8.601      2.718  -3.165  0.00165 **
# Psi          -38.334      5.914  -6.482 2.18e-10 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 62.51 on 497 degrees of freedom
# Multiple R-squared:  0.4409,	Adjusted R-squared:  0.4386
# F-statistic:   196 on 2 and 497 DF,  p-value: < 2.2e-16

# %%
AIC(mod1_d2)
BIC(mod1_d2)
# Out:
# [1] 5559.237
# [1] 5576.096

# %%
# Model 2 plus enzyme trait
mod2_d2 <- lm(decom ~ Temp + Psi + Enz, data=all_data_d2)
summary(mod2_d2)
# Out:
# Call:
# lm(formula = decom ~ Temp + Psi + Enz, data = all_data_d2)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -109.539  -33.879   -4.429   30.096  150.715
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  4.429e+02  4.250e+01  10.421  < 2e-16 ***
# Temp        -8.612e+00  2.067e+00  -4.166 3.66e-05 ***
# Psi         -3.836e+01  4.499e+00  -8.527  < 2e-16 ***
# Enz         -1.039e+05  5.458e+03 -19.045  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 47.56 on 496 degrees of freedom
# Multiple R-squared:  0.677,	Adjusted R-squared:  0.6751
# F-statistic: 346.6 on 3 and 496 DF,  p-value: < 2.2e-16

# %%
AIC(mod2_d2)
BIC(mod2_d2)
# Out:
# [1] 5286.818
# [1] 5307.891

# %%
# Model 3 with drt instead of enz
mod3_d2 <- lm(decom ~ Temp + Psi + Enz, data=all_data_d2)
summary(mod3_d2)
# Out:
# Call:
# lm(formula = decom ~ Temp + Psi + Enz, data = all_data_d2)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -109.539  -33.879   -4.429   30.096  150.715
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  4.429e+02  4.250e+01  10.421  < 2e-16 ***
# Temp        -8.612e+00  2.067e+00  -4.166 3.66e-05 ***
# Psi         -3.836e+01  4.499e+00  -8.527  < 2e-16 ***
# Enz         -1.039e+05  5.458e+03 -19.045  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 47.56 on 496 degrees of freedom
# Multiple R-squared:  0.677,	Adjusted R-squared:  0.6751
# F-statistic: 346.6 on 3 and 496 DF,  p-value: < 2.2e-16

# %%
AIC(mod3_d2)
BIC(mod3_d2)
# Out:
# [1] 5286.818
# [1] 5307.891

# %%
# Model 3 plus drought trait
mod4_d2 <- lm(decom ~ Temp + Psi + Enz + Drt, data=all_data_d2)
summary(mod4_d2)
# Out:
# Call:
# lm(formula = decom ~ Temp + Psi + Enz + Drt, data = all_data_d2)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -99.331 -32.086  -2.737  30.344 119.052
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)    340.789     38.802   8.783  < 2e-16 ***
# Temp            -8.610      1.838  -4.686 3.61e-06 ***
# Psi            -38.357      3.999  -9.592  < 2e-16 ***
# Enz         -86330.857   5085.530 -16.976  < 2e-16 ***
# Drt            108.772      9.436  11.528  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 42.27 on 495 degrees of freedom
# Multiple R-squared:  0.7454,	Adjusted R-squared:  0.7433
# F-statistic: 362.3 on 4 and 495 DF,  p-value: < 2.2e-16

# %%
AIC(mod4_d2)
BIC(mod4_d2)
# Out:
# [1] 5169.92
# [1] 5195.207

# %%
#################################
## with mean local temp and psi
################################

data_climate_d2m <- data_climate(climate_data)

data_sub_d2m <- data_anova(sub_data,1+365*4 + 365 - 1)
data_sub_d2m[,'decom'] <- data_sub_d2m$decom/10000
data_enz_d2m <- data_anova(enz_data,1+365*4 + 1) # first day
data_drt_d2m <- data_anova(drt_data,1+365*4 + 1) # first day


# concatenate the same day climate and decomposition and traits (last day of the 1st year)
# into one dataframe
all_data_d2m <- cbind(data_sub_d2m,data_climate_d2m, data_enz_d2m$decom,data_drt_d2m$decom)
names(all_data_d2m)[6] <- 'Enz'
names(all_data_d2m)[7] <- 'Drt'

head(all_data_d2m)
# Out:
#    origin site   decom    Temp     Psi       Enz         Drt
# X0 desert desert 260.4377 26.26845 -5.304724 0.001688039 0.9598001
# X1 desert desert 259.2960 26.26845 -5.304724 0.002173554 0.8839917
# X2 desert desert 289.8874 26.26845 -5.304724 0.001145072 0.9605490
# X3 desert desert 309.1437 26.26845 -5.304724 0.000590922 0.9160625
# X4 desert desert 255.3615 26.26845 -5.304724 0.001276322 0.9105744
# X5 desert desert 263.3692 26.26845 -5.304724 0.001928113 0.8970926

# %%
# Model 1 with only temp and psi
mod1_d2m <- lm(decom ~ Temp + Psi, data=all_data_d2m)
summary(mod1_d2m)
# Out:
# Call:
# lm(formula = decom ~ Temp + Psi, data = all_data_d2m)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -109.20  -47.55   -8.66   37.02  192.29
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   94.064     11.601   8.108 4.04e-15 ***
# Temp          -4.880      1.377  -3.545  0.00043 ***
# Psi          -52.522      5.123 -10.253  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 62.89 on 497 degrees of freedom
# Multiple R-squared:  0.434,	Adjusted R-squared:  0.4317
# F-statistic: 190.5 on 2 and 497 DF,  p-value: < 2.2e-16

# %%
AIC(mod1_d2m)
BIC(mod1_d2m)
# Out:
# [1] 5565.381
# [1] 5582.239

# %%
# Model 1 plus enzyme trait
mod2_d2m <- lm(decom ~ Temp + Psi + Enz, data=all_data_d2m)
summary(mod2_d2m)
# Out:
# Call:
# lm(formula = decom ~ Temp + Psi + Enz, data = all_data_d2m)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -107.033  -34.510   -3.968   33.328  145.421
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  2.907e+02  1.370e+01  21.230  < 2e-16 ***
# Temp        -4.884e+00  1.052e+00  -4.642 4.42e-06 ***
# Psi         -5.255e+01  3.915e+00 -13.423  < 2e-16 ***
# Enz         -1.039e+05  5.516e+03 -18.843  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 48.06 on 496 degrees of freedom
# Multiple R-squared:  0.6701,	Adjusted R-squared:  0.6681
# F-statistic: 335.8 on 3 and 496 DF,  p-value: < 2.2e-16

# %%
AIC(mod2_d2m)
BIC(mod2_d2m)
# Out:
# [1] 5297.439
# [1] 5318.512

# %%
# Model 1 plus drought trait
mod3_d2m <- lm(decom ~ Temp + Psi + Drt, data=all_data_d2m)
summary(mod3_d2m)
# Out:
# Call:
# lm(formula = decom ~ Temp + Psi + Drt, data = all_data_d2m)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -136.842  -39.248   -1.602   38.189  138.234
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   -5.150     12.234  -0.421    0.674
# Temp          -4.879      1.172  -4.162 3.72e-05 ***
# Psi          -52.517      4.363 -12.037  < 2e-16 ***
# Drt          156.880     11.406  13.754  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 53.57 on 496 degrees of freedom
# Multiple R-squared:  0.5902,	Adjusted R-squared:  0.5878
# F-statistic: 238.2 on 3 and 496 DF,  p-value: < 2.2e-16

# %%
AIC(mod3_d2m)
BIC(mod3_d2m)
# Out:
# [1] 5405.831
# [1] 5426.904

# %%
# Model 4 plus drought + enzyme trait
mod4_d2m <- lm(decom ~ Temp + Psi + Drt + Enz, data=all_data_d2m)
summary(mod4_d2m)
# Out:
# Call:
# lm(formula = decom ~ Temp + Psi + Drt + Enz, data = all_data_d2m)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -96.83 -32.98  -1.05  30.25 117.45
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  1.886e+02  1.515e+01  12.449  < 2e-16 ***
# Temp        -4.883e+00  9.376e-01  -5.208 2.81e-07 ***
# Psi         -5.254e+01  3.489e+00 -15.058  < 2e-16 ***
# Drt          1.088e+02  9.563e+00  11.374  < 2e-16 ***
# Enz         -8.633e+04  5.154e+03 -16.748  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 42.84 on 495 degrees of freedom
# Multiple R-squared:  0.7385,	Adjusted R-squared:  0.7363
# F-statistic: 349.4 on 4 and 495 DF,  p-value: < 2.2e-16

# %%
AIC(mod4_d2m)
BIC(mod4_d2m)
# Out:
# [1] 5183.352
# [1] 5208.639

# %% [markdown]
# #### 4th year

# %%
# environment of the last day 
data_climate_d3 <- data_climate(climate_data,200)

data_sub_d3 <- data_anova(sub_data,1+365*7 + 365 - 1)
data_sub_d3[,'decom'] <- data_sub_d3$decom/10000
# day 1
data_enz_d3 <- data_anova(enz_data,1+365*7 + 365 - 1)
data_drt_d3 <- data_anova(drt_data,1+365*7 + 365 - 1)

# concatenate the same day climate and decomposition and traits (last day of the 1st year)
# into one dataframe
all_data_d3 <- cbind(data_sub_d3,data_climate_d3, data_enz_d3$decom,data_drt_d3$decom)
names(all_data_d3)[6] <- 'Enz'
names(all_data_d3)[7] <- 'Drt'
head(all_data_d3)
# Out:
#    origin site   decom    Temp     Psi       Enz          Drt
# X0 desert desert 269.9034 38.51389 -8.498463 0.0015693954 0.9723694
# X1 desert desert 261.5293 38.51389 -8.498463 0.0021875966 0.8845438
# X2 desert desert 290.3816 38.51389 -8.498463 0.0010842525 0.9636903
# X3 desert desert 310.0326 38.51389 -8.498463 0.0005521731 0.9141868
# X4 desert desert 257.3524 38.51389 -8.498463 0.0013245111 0.9155219
# X5 desert desert 272.3189 38.51389 -8.498463 0.0018966636 0.9099207

# %%
# Model 1 
mod1_d3 <- lm(decom ~ Temp + Psi, data=all_data_d3)
summary(mod1_d3)
# Out:
# Call:
# lm(formula = decom ~ Temp + Psi, data = all_data_d3)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -94.867 -38.559  -8.202  31.508 210.195
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  180.217     46.291   3.893 0.000112 ***
# Temp          -6.814      2.321  -2.935 0.003488 **
# Psi          -42.077      5.052  -8.329 7.97e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 53.4 on 497 degrees of freedom
# Multiple R-squared:  0.6694,	Adjusted R-squared:  0.6681
# F-statistic: 503.2 on 2 and 497 DF,  p-value: < 2.2e-16

# %%
AIC(mod1_d3)
BIC(mod1_d3)
# Out:
# [1] 5401.673
# [1] 5418.532

# %%
# Model 2 
mod2_d3 <- lm(decom ~ Temp + Psi + Enz, data=all_data_d3)
summary(mod2_d3)
# Out:
# Call:
# lm(formula = decom ~ Temp + Psi + Enz, data = all_data_d3)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -93.827 -34.732  -2.536  23.975 172.627
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)    378.285     40.625   9.312  < 2e-16 ***
# Temp            -9.535      1.935  -4.927 1.14e-06 ***
# Psi            -45.143      4.198 -10.753  < 2e-16 ***
# Enz         -70618.836   4703.714 -15.013  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 44.32 on 496 degrees of freedom
# Multiple R-squared:  0.7727,	Adjusted R-squared:  0.7713
# F-statistic: 562.1 on 3 and 496 DF,  p-value: < 2.2e-16

# %%
AIC(mod2_d3)
BIC(mod2_d3)
# Out:
# [1] 5216.363
# [1] 5237.436

# %%
# Model 3
mod3_d3 <- lm(decom ~ Temp + Psi + Drt, data=all_data_d3)
summary(mod3_d3)
# Out:
# Call:
# lm(formula = decom ~ Temp + Psi + Drt, data = all_data_d3)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -105.920  -37.282   -4.786   33.736  151.170
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   14.738     46.650   0.316    0.752
# Temp          -2.143      2.213  -0.968    0.333
# Psi          -23.712      5.104  -4.646 4.35e-06 ***
# Drt          156.509     17.280   9.057  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 49.51 on 496 degrees of freedom
# Multiple R-squared:  0.7163,	Adjusted R-squared:  0.7146
# F-statistic: 417.5 on 3 and 496 DF,  p-value: < 2.2e-16

# %%
AIC(mod3_d3)
BIC(mod3_d3)
# Out:
# [1] 5327.142
# [1] 5348.215

# %%
# Model 3 
mod4_d3 <- lm(decom ~ Temp + Psi + Enz + Drt, data=all_data_d3)
summary(mod4_d3)
# Out:
# Call:
# lm(formula = decom ~ Temp + Psi + Enz + Drt, data = all_data_d3)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -94.347 -32.964  -2.782  27.851 130.873
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)    242.224     43.141   5.615 3.29e-08 ***
# Temp            -6.006      1.909  -3.146  0.00176 **
# Psi            -32.096      4.397  -7.299 1.16e-12 ***
# Enz         -62953.956   4609.175 -13.658  < 2e-16 ***
# Drt            108.353     15.157   7.149 3.16e-12 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 42.24 on 495 degrees of freedom
# Multiple R-squared:  0.794,	Adjusted R-squared:  0.7923
# F-statistic: 476.9 on 4 and 495 DF,  p-value: < 2.2e-16

# %%
AIC(mod4_d3)
BIC(mod4_d3)
# Out:
# [1] 5169.235
# [1] 5194.522

# %%
########################
# mean environment of the whole year
########################

data_climate_d3m <- data_climate(climate_data)

data_sub_d3m <- data_anova(sub_data,1+365*7 + 365 - 1)
data_sub_d3m[,'decom'] <- data_sub_d3m$decom/10000
# day 1
data_enz_d3m <- data_anova(enz_data,1+365*7 + 365 - 1)
data_drt_d3m <- data_anova(drt_data,1+365*7 + 365 - 1)

# concatenate the same day climate and decomposition and traits (last day of the 1st year)
# into one dataframe
all_data_d3m <- cbind(data_sub_d3m,data_climate_d3m, data_enz_d3m$decom,data_drt_d3m$decom)
names(all_data_d3m)[6] <- 'Enz'
names(all_data_d3m)[7] <- 'Drt'
head(all_data_d3m)
# Out:
#    origin site   decom    Temp     Psi       Enz          Drt
# X0 desert desert 269.9034 26.26845 -5.304724 0.0015693954 0.9723694
# X1 desert desert 261.5293 26.26845 -5.304724 0.0021875966 0.8845438
# X2 desert desert 290.3816 26.26845 -5.304724 0.0010842525 0.9636903
# X3 desert desert 310.0326 26.26845 -5.304724 0.0005521731 0.9141868
# X4 desert desert 257.3524 26.26845 -5.304724 0.0013245111 0.9155219
# X5 desert desert 272.3189 26.26845 -5.304724 0.0018966636 0.9099207

# %%
# Model 1 
mod1_d3m <- lm(decom ~ Temp + Psi, data=all_data_d3m)
summary(mod1_d3m)
# Out:
# Call:
# lm(formula = decom ~ Temp + Psi, data = all_data_d3m)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -91.630 -40.373  -4.036  29.535 197.537
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   52.041      9.936   5.238 2.41e-07 ***
# Temp          -4.239      1.179  -3.595 0.000357 ***
# Psi          -64.098      4.387 -14.609  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 53.87 on 497 degrees of freedom
# Multiple R-squared:  0.6636,	Adjusted R-squared:  0.6622
# F-statistic: 490.2 on 2 and 497 DF,  p-value: < 2.2e-16

# %%
AIC(mod1_d3m)
BIC(mod1_d3m)
# Out:
# [1] 5410.421
# [1] 5427.28

# %%
# Model 2 
mod2_d3m <- lm(decom ~ Temp + Psi + Enz, data=all_data_d3m)
summary(mod2_d3m)
# Out:
# Call:
# lm(formula = decom ~ Temp + Psi + Enz, data = all_data_d3m)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -91.082 -33.588  -1.192  27.417 169.574
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  2.061e+02  1.340e+01  15.386  < 2e-16 ***
# Temp        -5.391e+00  9.889e-01  -5.452 7.88e-08 ***
# Psi         -6.302e+01  3.669e+00 -17.176  < 2e-16 ***
# Enz         -7.008e+04  4.780e+03 -14.660  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 45.04 on 496 degrees of freedom
# Multiple R-squared:  0.7653,	Adjusted R-squared:  0.7639
# F-statistic: 539.1 on 3 and 496 DF,  p-value: < 2.2e-16

# %%
AIC(mod2_d3m)
BIC(mod2_d3m)
# Out:
# [1] 5232.422
# [1] 5253.495

# %%
# Model 3 
mod3_d3m <- lm(decom ~ Temp + Psi + Drt, data=all_data_d3m)
summary(mod3_d3m)
# Out:
# Call:
# lm(formula = decom ~ Temp + Psi + Drt, data = all_data_d3m)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -96.18 -38.86  -3.81  35.28 140.97
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -23.098     12.076  -1.913  0.05636 .
# Temp          -3.128      1.091  -2.866  0.00433 **
# Psi          -44.809      4.517  -9.920  < 2e-16 ***
# Drt          160.413     16.839   9.526  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 49.57 on 496 degrees of freedom
# Multiple R-squared:  0.7156,	Adjusted R-squared:  0.7139
# F-statistic:   416 on 3 and 496 DF,  p-value: < 2.2e-16

# %%
AIC(mod3_d3m)
BIC(mod3_d3m)
# Out:
# [1] 5328.406
# [1] 5349.48

# %%
# Model 4 
mod4_d3m <- lm(decom ~ Temp + Psi + Enz + Drt, data=all_data_d3m)
summary(mod4_d3m)
# Out:
# Call:
# lm(formula = decom ~ Temp + Psi + Enz + Drt, data = all_data_d3m)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -93.596 -33.783  -0.116  27.741 121.948
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  1.334e+02  1.549e+01   8.615  < 2e-16 ***
# Temp        -4.441e+00  9.379e-01  -4.735 2.87e-06 ***
# Psi         -4.885e+01  3.873e+00 -12.614  < 2e-16 ***
# Enz         -6.234e+04  4.599e+03 -13.556  < 2e-16 ***
# Drt          1.188e+02  1.472e+01   8.075 5.19e-15 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 42.38 on 495 degrees of freedom
# Multiple R-squared:  0.7926,	Adjusted R-squared:  0.7909
# F-statistic: 472.9 on 4 and 495 DF,  p-value: < 2.2e-16

# %%
AIC(mod4_d3m)
BIC(mod4_d3m)
# Out:
# [1] 5172.556
# [1] 5197.844

# %% [markdown]
# ## 3. Model validation
#
# Validate the decomposition model derived from transplant data with the data before transplant

# %%
sub_anova_origin <- data_anova(sub_data,1+365*3 + 365 - 1) # substrate
sub_anova_origin[,'decom'] <- sub_anova_origin$decom/10000
drt_anova_origin <- data_anova(drt_data,1+365*3) # drought trait
enz_anova_origin <- data_anova(enz_data,1+365*3) # enzyme trait

all_data_d0 <- cbind(sub_anova_origin,data_climate_d2, enz_anova_origin$decom,drt_anova_origin$decom)

names(all_data_d0)[6] <- 'Enz'
names(all_data_d0)[7] <- 'Drt'
head(all_data_d0)
# Out:
#    origin site   decom    Temp     Psi       Enz          Drt
# X0 desert desert 255.7969 38.51389 -8.498463 0.0017441899 0.9538912
# X1 desert desert 259.8060 38.51389 -8.498463 0.0021854136 0.8841575
# X2 desert desert 288.0928 38.51389 -8.498463 0.0012227752 0.9524790
# X3 desert desert 307.3738 38.51389 -8.498463 0.0006593236 0.9180293
# X4 desert desert 255.9100 38.51389 -8.498463 0.0012906085 0.9050124
# X5 desert desert 256.6868 38.51389 -8.498463 0.0019116473 0.8900117

# %%
decomp_predic = -8.610*all_data_d0$Temp + (-38.357)*all_data_d0$Psi +
                (-86330.857)*all_data_d0$Enz + 108.772*all_data_d0$Drt  + 340.789

# %%
plot(all_data_d0$decom,decomp_predic,col='blue')
lines(decomp_predic, decomp_predic,col="red")
# Out:
# plot without title

# %%
to_python <- cbind(all_data_d0$decom,decomp_predic)
write.csv(to_python,'model_validation.csv')

# %%
res <- cor(all_data_d0$decom, decomp_predic, method = "pearson")
cat('R=',res)
# Out:
# R2= 0.4588212

# %%
RMSE = sqrt(mean((decomp_predic - all_data_d0$decom)^2))
cat('RMSE=',RMSE)
# Out:
# RMSE= 88.28066
